# %%
import pybedtools as pbt
import pysam
import pandas as pd
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt

# %%
import os.path as op

# %%
import splanl.junction_scorer as jn
import splanl.merge_bcs as mbcs
import splanl.coords as coords
import splanl.plots as sp
import splanl.score_motifs as sm
import splanl.inspect_variants as iv
import splanl.post_processing as pp
# Out:
# Using TensorFlow backend.

# %%
fa_file = '/nfs/kitzman2/jacob/proj/jensplice/20220415_wt1_mpsa_trial3/jkp1053_1054_1055.fa'

# %%
refseq = pp.get_refseq( fa_file )

# %%
bam1 = ! ls /nfs/kitzman2/jacob/proj/jensplice/20220513_wt1_mpsa_trial4and3_deep_redoAligns/process_star/BB_test*/*out.wbcs.bam

# %%
bam2 = ! ls /nfs/kitzman2/jacob/proj/jensplice/20220513_wt1_mpsa_trial4and3_deep_redoAligns/process_star/BB_RT*/*out.wbcs.bam

# %%
bam1
# Out:
# ['/nfs/kitzman2/jacob/proj/jensplice/20220513_wt1_mpsa_trial4and3_deep_redoAligns/process_star/BB_test_Cos1053_JKLab0340_MM1B/BB_test_Cos1053_JKLab0340_MM1BAligned.out.wbcs.bam',
#  '/nfs/kitzman2/jacob/proj/jensplice/20220513_wt1_mpsa_trial4and3_deep_redoAligns/process_star/BB_test_Cos1053_JKLab0340_MM2B/BB_test_Cos1053_JKLab0340_MM2BAligned.out.wbcs.bam',
#  '/nfs/kitzman2/jacob/proj/jensplice/20220513_wt1_mpsa_trial4and3_deep_redoAligns/process_star/BB_test_Cos1053_oligodT_MM1B/BB_test_Cos1053_oligodT_MM1BAligned.out.wbcs.bam',
#  '/nfs/kitzman2/jacob/proj/jensplice/20220513_wt1_mpsa_trial4and3_deep_redoAligns/process_star/BB_test_Cos1053_oligodT_MM2B/BB_test_Cos1053_oligodT_MM2BAligned.out.wbcs.bam']

# %%
bam2
# Out:
# ['/nfs/kitzman2/jacob/proj/jensplice/20220422_wt1_mpsa_trial4and3_deep/process_star/BB_RT_1_340_243_Cos1053/BB_RT_1_340_243_Cos1053Aligned.out.wbcs.bam',
#  '/nfs/kitzman2/jacob/proj/jensplice/20220422_wt1_mpsa_trial4and3_deep/process_star/BB_RT_1_340_243_Hek1053/BB_RT_1_340_243_Hek1053Aligned.out.wbcs.bam',
#  '/nfs/kitzman2/jacob/proj/jensplice/20220422_wt1_mpsa_trial4and3_deep/process_star/BB_RT_1_340_335_Cos1053/BB_RT_1_340_335_Cos1053Aligned.out.wbcs.bam',
#  '/nfs/kitzman2/jacob/proj/jensplice/20220422_wt1_mpsa_trial4and3_deep/process_star/BB_RT_1_340_335_Hek1053/BB_RT_1_340_335_Hek1053Aligned.out.wbcs.bam',
#  '/nfs/kitzman2/jacob/proj/jensplice/20220422_wt1_mpsa_trial4and3_deep/process_star/BB_RT_1b_340_243_Hek1053/BB_RT_1b_340_243_Hek1053Aligned.out.wbcs.bam',
#  '/nfs/kitzman2/jacob/proj/jensplice/20220422_wt1_mpsa_trial4and3_deep/process_star/BB_RT_1b_340_335_Hek1053/BB_RT_1b_340_335_Hek1053Aligned.out.wbcs.bam',
#  '/nfs/kitzman2/jacob/proj/jensplice/20220422_wt1_mpsa_trial4and3_deep/process_star/BB_RT_3_340_243_Hek1055/BB_RT_3_340_243_Hek1055Aligned.out.wbcs.bam',
#  '/nfs/kitzman2/jacob/proj/jensplice/20220422_wt1_mpsa_trial4and3_deep/process_star/BB_RT_3_340_335_Cos1055/BB_RT_3_340_335_Cos1055Aligned.out.wbcs.bam',
#  '/nfs/kitzman2/jacob/proj/jensplice/20220422_wt1_mpsa_trial4and3_deep/process_star/BB_RT_3_340_335_Hek1055/BB_RT_3_340_335_Hek1055Aligned.out.wbcs.bam',
#  '/nfs/kitzman2/jacob/proj/jensplice/20220422_wt1_mpsa_trial4and3_deep/process_star/BB_RT_3_ODT_243_Cos1055/BB_RT_3_ODT_243_Cos1055Aligned.out.wbcs.bam',
#  '/nfs/kitzman2/jacob/proj/jensplice/20220422_wt1_mpsa_trial4and3_deep/process_star/BB_RT_3_ODT_243_Hek1055/BB_RT_3_ODT_243_Hek1055Aligned.out.wbcs.bam',
#  '/nfs/kitzman2/jacob/proj/jensplice/20220422_wt1_mpsa_trial4and3_deep/process_star/BB_RT_3_ODT_335_cos1055/BB_RT_3_ODT_335_cos1055Aligned.out.wbcs.bam',
#  '/nfs/kitzman2/jacob/proj/jensplice/20220422_wt1_mpsa_trial4and3_deep/process_star/BB_RT_3_ODT_335_Hek1055/BB_RT_3_ODT_335_Hek1055Aligned.out.wbcs.bam']

# %%
bam = bam1 + bam2

# %%
msamp_fn = { b.split( '/')[ -1 ].split( '.' )[ 0 ].replace( 'Aligned', '' ) : b for b in bam }

# %%
msamp_fn
# Out:
# {'BB_test_Cos1053_JKLab0340_MM1B': '/nfs/kitzman2/jacob/proj/jensplice/20220513_wt1_mpsa_trial4and3_deep_redoAligns/process_star/BB_test_Cos1053_JKLab0340_MM1B/BB_test_Cos1053_JKLab0340_MM1BAligned.out.wbcs.bam',
#  'BB_test_Cos1053_JKLab0340_MM2B': '/nfs/kitzman2/jacob/proj/jensplice/20220513_wt1_mpsa_trial4and3_deep_redoAligns/process_star/BB_test_Cos1053_JKLab0340_MM2B/BB_test_Cos1053_JKLab0340_MM2BAligned.out.wbcs.bam',
#  'BB_test_Cos1053_oligodT_MM1B': '/nfs/kitzman2/jacob/proj/jensplice/20220513_wt1_mpsa_trial4and3_deep_redoAligns/process_star/BB_test_Cos1053_oligodT_MM1B/BB_test_Cos1053_oligodT_MM1BAligned.out.wbcs.bam',
#  'BB_test_Cos1053_oligodT_MM2B': '/nfs/kitzman2/jacob/proj/jensplice/20220513_wt1_mpsa_trial4and3_deep_redoAligns/process_star/BB_test_Cos1053_oligodT_MM2B/BB_test_Cos1053_oligodT_MM2BAligned.out.wbcs.bam',
#  'BB_RT_1_340_243_Cos1053': '/nfs/kitzman2/jacob/proj/jensplice/20220422_wt1_mpsa_trial4and3_deep/process_star/BB_RT_1_340_243_Cos1053/BB_RT_1_340_243_Cos1053Aligned.out.wbcs.bam',
#  'BB_RT_3_ODT_335_cos1055': '/nfs/kitzman2/jacob/proj/jensplice/20220422_wt1_mpsa_trial4and3_deep/process_star/BB_RT_3_ODT_335_cos1055/BB_RT_3_ODT_335_cos1055Aligned.out.wbcs.bam',
#  'BB_RT_3_ODT_335_Hek1055': '/nfs/kitzman2/jacob/proj/jensplice/20220422_wt1_mpsa_trial4and3_deep/process_star/BB_RT_3_ODT_335_Hek1055/BB_RT_3_ODT_335_Hek1055Aligned.out.wbcs.bam'}

# %%
msamp_rnabam = { samp: pysam.AlignmentFile( msamp_fn[ samp ], 'rb' ) for samp in msamp_fn }

# %%
# %%time
#I made this more stringent than MSH2 since there is less skipping
#requiring 90 forward and 70 reverse matches
isos_dfs = { samp: jn.get_all_isoforms_pe( msamp_rnabam[ samp ],
                                           [ ( 649, 696 ), ( 3478, 3533 ) ],
                                            spl_tol = 3,
                                            indel_tol = 20,
                                            min_matches_for = 90,
                                            min_matches_rev = 70 )
             for samp in msamp_rnabam }

# %%
for samp in isos_dfs.keys():
    
    print( samp )
    
    print( isos_dfs[ samp ].head() )
# Out:
# BB_test_Cos1053_JKLab0340_MM1B
#                  read_count
# isoform
# ((1267, 1359),)     2398566
# ((1267, 1350),)     2199618
# ((1284, 1359),)       17744
# ((1284, 1350),)       12115
# ((1268, 1350),)        5905
# BB_test_Cos1053_JKLab0340_MM2B
#                  read_count
# isoform
# ((1267, 1359),)     5042945
# ((1267, 1350),)     4600777
# ((1284, 1359),)       39501
# ((1284, 1350),)       23727
# ((1268, 1350),)       13542
# BB_test_Cos1053_oligodT_MM1B
#                  read_count
# isoform
# ((1267, 1359),)     2188404
# ((1267, 1350),)     1959934
# ((1284, 1359),)       17534
# ((1284, 1350),)       11526
# ((1268, 1350),)        5871
# BB_test_Cos1053_oligodT_MM2B
#                  read_count
# isoform
# ((1267, 1359),)     6167843
# ((1267, 1350),)     5723480
# ((1284, 1359),)       44962
# ((1284, 1350),)       30212
# ((1269, 1350),)       17823
# BB_RT_1_340_243_Cos1053
#                  read_count
# isoform
# ((1267, 1359),)     1848512
# ((1267, 1350),)     1639853
# ()                    22819
# ((1284, 1359),)       14614
# ((1284, 1350),)        6923
# BB_RT_1_340_243_Hek1053
#                  read_count
# isoform
# ((1267, 1359),)     3402477
# ((1267, 1350),)     3024211
# ()                    37131
# ((1284, 1359),)       17490
# ((1284, 1350),)       10866
# BB_RT_1_340_335_Cos1053
#                  read_count
# isoform
# ((1267, 1359),)      498991
# ((1267, 1350),)      456880
# ()                    96360
# ((1284, 1359),)        5462
# ((1284, 1350),)        2798
# BB_RT_1_340_335_Hek1053
#                  read_count
# isoform
# ((1267, 1359),)     1002709
# ((1267, 1350),)      942554
# ()                   132449
# ((1284, 1359),)        6478
# ((1284, 1350),)        4096
# BB_RT_1b_340_243_Hek1053
#                  read_count
# isoform
# ((1267, 1359),)     3088366
# ((1267, 1350),)     2722208
# ()                    36018
# ((1284, 1359),)       15574
# ((1284, 1350),)        9576
# BB_RT_1b_340_335_Hek1053
#                  read_count
# isoform
# ((1267, 1359),)      914707
# ((1267, 1350),)      855525
# ()                   123341
# ((1284, 1359),)        5862
# ((1284, 1350),)        3712
# BB_RT_1b_ODT_243_Hek1053
#                  read_count
# isoform
# ((1267, 1359),)     2729027
# ((1267, 1350),)     2353073
# ()                    27221
# ((1284, 1359),)       13636
# ((1284, 1350),)        7792
# BB_RT_1b_ODT_335_Hek1053
#                  read_count
# isoform
# ((1267, 1359),)      516364
# ((1267, 1350),)      501999
# ()                    64281
# ((1284, 1359),)        3263
# ((1284, 1350),)        2181
# BB_RT_1_ODT_243_Cos1053
#                  read_count
# isoform
# ((1267, 1359),)     2376927
# ((1267, 1350),)     2072321
# ()                    29648
# ((1284, 1359),)       20225
# ((1284, 1350),)        9641
# BB_RT_1_ODT_243_Hek1053
#                  read_count
# isoform
# ((1267, 1359),)     3545713
# ((1267, 1350),)     3050240
# ()                    35648
# ((1284, 1359),)       17731
# ((1284, 1350),)       10586
# BB_RT_1_ODT_335_Cos1053
#                  read_count
# isoform
# ((1267, 1359),)      247994
# ((1267, 1350),)      226588
# ()                    52648
# ((1284, 1359),)        2291
# ((1284, 1350),)        1718
# BB_RT_1_ODT_335_Hek1053
#                  read_count
# isoform
# ((1267, 1359),)     1524430
# ((1267, 1350),)     1449588
# ()                   184211
# ((1284, 1359),)        9810
# ((1284, 1350),)        6515
# BB_RT_2_340_243_Cos1054
#                  read_count
# isoform
# ((1267, 1359),)     1505615
# ((1267, 1350),)     1332843
# ((1284, 1359),)       11324
# ()                     9521
# ((1284, 1350),)        7095
# BB_RT_2_340_243_Hek1054
#                  read_count
# isoform
# ((1267, 1359),)     2690786
# ((1267, 1350),)     2419226
# ()                    21302
# ((1284, 1359),)       15913
# ((1284, 1350),)       10279
# BB_RT_2_340_335_Cos1054
#                  read_count
# isoform
# ((1267, 1359),)      223681
# ((1267, 1350),)      208283
# ()                    25169
# ((1284, 1359),)        2584
# ((1284, 1350),)        1569
# BB_RT_2_340_335_Hek1054
#                  read_count
# isoform
# ((1267, 1359),)      966053
# ((1267, 1350),)      920468
# ()                   107380
# ((1284, 1359),)        7022
# ((1284, 1350),)        4761
# BB_RT_2_ODT_243_Cos1054
#                  read_count
# isoform
# ((1267, 1359),)     1803604
# ((1267, 1350),)     1607293
# ((1284, 1359),)       13375
# ()                    13095
# ((1284, 1350),)        5508
# BB_RT_2_ODT_243_Hek1054
#                  read_count
# isoform
# ((1267, 1359),)     2990925
# ((1267, 1350),)     2637156
# ()                    23355
# ((1284, 1359),)       17248
# ((1284, 1350),)       10845
# BB_RT_2_ODT_335_Cos1054
#                  read_count
# isoform
# ((1267, 1359),)      147916
# ((1267, 1350),)      131835
# ()                    18309
# ((1284, 1359),)        1614
# ((1284, 1350),)        1050
# BB_RT_2_ODT_335_Hek1054
#                  read_count
# isoform
# ((1267, 1359),)      670428
# ((1267, 1350),)      643764
# ()                    73004
# ((1284, 1359),)        4828
# ((1284, 1350),)        3495
# BB_RT_3_340_243_Cos1055
#                  read_count
# isoform
# ((1267, 1359),)      933746
# ((1267, 1350),)      853122
# ()                     8571
# ((1284, 1359),)        7751
# ((1284, 1350),)        4328
# BB_RT_3_340_243_Hek1055
#                  read_count
# isoform
# ((1267, 1359),)     2231420
# ((1267, 1350),)     1925365
# ((1284, 1359),)       13611
# ()                    13059
# ((1284, 1350),)        8057
# BB_RT_3_340_335_Cos1055
#                  read_count
# isoform
# ((1267, 1359),)      641615
# ((1267, 1350),)      606692
# ()                   112560
# ((1284, 1359),)        7451
# ((1284, 1350),)        4250
# BB_RT_3_340_335_Hek1055
#                  read_count
# isoform
# ((1267, 1350),)     1466165
# ((1267, 1359),)     1423772
# ()                   119731
# ((1284, 1359),)       11654
# ((1284, 1350),)        9844
# BB_RT_3_ODT_243_Cos1055
#                  read_count
# isoform
# ((1267, 1359),)     2632227
# ((1267, 1350),)     2361296
# ()                    31961
# ((1284, 1359),)       23469
# ((1284, 1350),)       13385
# BB_RT_3_ODT_243_Hek1055
#                  read_count
# isoform
# ((1267, 1359),)     1602454
# ((1267, 1350),)     1371133
# ((1284, 1359),)        9722
# ()                     9376
# ((1284, 1350),)        5595
# BB_RT_3_ODT_335_cos1055
#                  read_count
# isoform
# ((1267, 1359),)      768075
# ((1267, 1350),)      728819
# ()                   162737
# ((1284, 1359),)        8612
# ((1284, 1350),)        5278
# BB_RT_3_ODT_335_Hek1055
#                  read_count
# isoform
# ((1267, 1350),)     1187498
# ((1267, 1359),)     1087995
# ()                    74199
# ((1284, 1359),)        9131
# ((1284, 1350),)        7920

# %%
# %%time
isogrp_df = jn.number_and_merge_isoforms( isos_dfs )

# %%
isogrp_df.head()
# Out:
#                               isoform  \
# isonum
# iso0000  ((1136, 1225), (1301, 1350))
# iso0001  ((1267, 1290), (1320, 1350))
# iso0002  ((1267, 1314), (1337, 1359))
# iso0003  ((1267, 1282), (1328, 1359))
# iso0004  ((1136, 1224), (1306, 1359))
#
#          BB_test_Cos1053_JKLab0340_MM1B_read_count  \
# isonum
# iso0000                                          0
# iso0001                                          0
# iso0002                                          1
# iso0003                                          0
# iso0004                                          0
#
#          BB_test_Cos1053_JKLab0340_MM2B_read_count  \
# isonum
# iso0000                                          0
# iso0001                                          0
# iso0002                                        272
# iso0003                                          0
# iso0004                                          0
#
#          BB_test_Cos1053_oligodT_MM1B_read_count  \
# isonum
# iso0000                                        0
# iso0001                                        0
# iso0002                                        0
# iso0003                                        2
# iso0004                                        0
#
#          BB_test_Cos1053_oligodT_MM2B_read_count  \
# isonum
# iso0000                                        0
# iso0001                                        0
# iso0002                                        0
# iso0003                                        0
# iso0004                                        0
#
#          BB_RT_1_340_243_Cos1053_read_count  \
# isonum
# iso0000                                   0
# iso0001                                   0
# iso0002                                   1
# iso0003                                   0
# iso0004                                   0
#
#          BB_RT_1_340_243_Hek1053_read_count  \
# isonum
# iso0000                                   0
# iso0001                                   0
# iso0002                                 127
# iso0003                                   0
# iso0004                                   1
#
#          BB_RT_1_340_335_Cos1053_read_count  \
# isonum
# iso0000                                   0
# iso0001                                   0
# iso0002                                  64
# iso0003                                   0
# iso0004                                   0
#
#          BB_RT_1_340_335_Hek1053_read_count  \
# isonum
# iso0000                                   0
# iso0001                                   0
# iso0002                                  59
# iso0003                                   1
# iso0004                                   0
#
#          BB_RT_1b_340_243_Hek1053_read_count  ...  \
# isonum                                        ...
# iso0000                                    0  ...
# iso0001                                    0  ...
# iso0002                                  140  ...
# iso0003                                    0  ...
# iso0004                                    2  ...
#
#          BB_RT_2_ODT_335_Cos1054_read_count  \
# isonum
# iso0000                                   0
# iso0001                                   0
# iso0002                                   0
# iso0003                                   0
# iso0004                                   0
#
#          BB_RT_2_ODT_335_Hek1054_read_count  \
# isonum
# iso0000                                   0
# iso0001                                   0
# iso0002                                   0
# iso0003                                   0
# iso0004                                   0
#
#          BB_RT_3_340_243_Cos1055_read_count  \
# isonum
# iso0000                                   0
# iso0001                                   0
# iso0002                                   0
# iso0003                                   0
# iso0004                                   0
#
#          BB_RT_3_340_243_Hek1055_read_count  \
# isonum
# iso0000                                   0
# iso0001                                   0
# iso0002                                   0
# iso0003                                   0
# iso0004                                   0
#
#          BB_RT_3_340_335_Cos1055_read_count  \
# isonum
# iso0000                                   0
# iso0001                                   0
# iso0002                                   0
# iso0003                                   0
# iso0004                                   0
#
#          BB_RT_3_340_335_Hek1055_read_count  \
# isonum
# iso0000                                   0
# iso0001                                   0
# iso0002                                   0
# iso0003                                   0
# iso0004                                   0
#
#          BB_RT_3_ODT_243_Cos1055_read_count  \
# isonum
# iso0000                                   0
# iso0001                                   0
# iso0002                                   0
# iso0003                                   0
# iso0004                                   0
#
#          BB_RT_3_ODT_243_Hek1055_read_count  \
# isonum
# iso0000                                   0
# iso0001                                   0
# iso0002                                   0
# iso0003                                   0
# iso0004                                   0
#
#          BB_RT_3_ODT_335_cos1055_read_count  \
# isonum
# iso0000                                   0
# iso0001                                   0
# iso0002                                   0
# iso0003                                   0
# iso0004                                   0
#
#          BB_RT_3_ODT_335_Hek1055_read_count
# isonum
# iso0000                                   0
# iso0001                                   0
# iso0002                                   0
# iso0003                                   0
# iso0004                                   0
#
# [5 rows x 33 columns]

# %%
isogrp_df.loc[ isogrp_df.isoform == ((1267, 1359),) ]
# Out:
#                  isoform  BB_test_Cos1053_JKLab0340_MM1B_read_count  \
# isonum
# iso2293  ((1267, 1359),)                                    2398566
#
#          BB_test_Cos1053_JKLab0340_MM2B_read_count  \
# isonum
# iso2293                                    5042945
#
#          BB_test_Cos1053_oligodT_MM1B_read_count  \
# isonum
# iso2293                                  2188404
#
#          BB_test_Cos1053_oligodT_MM2B_read_count  \
# isonum
# iso2293                                  6167843
#
#          BB_RT_1_340_243_Cos1053_read_count  \
# isonum
# iso2293                             1848512
#
#          BB_RT_1_340_243_Hek1053_read_count  \
# isonum
# iso2293                             3402477
#
#          BB_RT_1_340_335_Cos1053_read_count  \
# isonum
# iso2293                              498991
#
#          BB_RT_1_340_335_Hek1053_read_count  \
# isonum
# iso2293                             1002709
#
#          BB_RT_1b_340_243_Hek1053_read_count  ...  \
# isonum                                        ...
# iso2293                              3088366  ...
#
#          BB_RT_2_ODT_335_Cos1054_read_count  \
# isonum
# iso2293                              147916
#
#          BB_RT_2_ODT_335_Hek1054_read_count  \
# isonum
# iso2293                              670428
#
#          BB_RT_3_340_243_Cos1055_read_count  \
# isonum
# iso2293                              933746
#
#          BB_RT_3_340_243_Hek1055_read_count  \
# isonum
# iso2293                             2231420
#
#          BB_RT_3_340_335_Cos1055_read_count  \
# isonum
# iso2293                              641615
#
#          BB_RT_3_340_335_Hek1055_read_count  \
# isonum
# iso2293                             1423772
#
#          BB_RT_3_ODT_243_Cos1055_read_count  \
# isonum
# iso2293                             2632227
#
#          BB_RT_3_ODT_243_Hek1055_read_count  \
# isonum
# iso2293                             1602454
#
#          BB_RT_3_ODT_335_cos1055_read_count  \
# isonum
# iso2293                              768075
#
#          BB_RT_3_ODT_335_Hek1055_read_count
# isonum
# iso2293                             1087995
#
# [1 rows x 33 columns]

# %%
isogrp_df.loc[ isogrp_df.isoform == ((1267, 1350),) ]
# Out:
#                  isoform  BB_test_Cos1053_JKLab0340_MM1B_read_count  \
# isonum
# iso1187  ((1267, 1350),)                                    2199618
#
#          BB_test_Cos1053_JKLab0340_MM2B_read_count  \
# isonum
# iso1187                                    4600777
#
#          BB_test_Cos1053_oligodT_MM1B_read_count  \
# isonum
# iso1187                                  1959934
#
#          BB_test_Cos1053_oligodT_MM2B_read_count  \
# isonum
# iso1187                                  5723480
#
#          BB_RT_1_340_243_Cos1053_read_count  \
# isonum
# iso1187                             1639853
#
#          BB_RT_1_340_243_Hek1053_read_count  \
# isonum
# iso1187                             3024211
#
#          BB_RT_1_340_335_Cos1053_read_count  \
# isonum
# iso1187                              456880
#
#          BB_RT_1_340_335_Hek1053_read_count  \
# isonum
# iso1187                              942554
#
#          BB_RT_1b_340_243_Hek1053_read_count  ...  \
# isonum                                        ...
# iso1187                              2722208  ...
#
#          BB_RT_2_ODT_335_Cos1054_read_count  \
# isonum
# iso1187                              131835
#
#          BB_RT_2_ODT_335_Hek1054_read_count  \
# isonum
# iso1187                              643764
#
#          BB_RT_3_340_243_Cos1055_read_count  \
# isonum
# iso1187                              853122
#
#          BB_RT_3_340_243_Hek1055_read_count  \
# isonum
# iso1187                             1925365
#
#          BB_RT_3_340_335_Cos1055_read_count  \
# isonum
# iso1187                              606692
#
#          BB_RT_3_340_335_Hek1055_read_count  \
# isonum
# iso1187                             1466165
#
#          BB_RT_3_ODT_243_Cos1055_read_count  \
# isonum
# iso1187                             2361296
#
#          BB_RT_3_ODT_243_Hek1055_read_count  \
# isonum
# iso1187                             1371133
#
#          BB_RT_3_ODT_335_cos1055_read_count  \
# isonum
# iso1187                              728819
#
#          BB_RT_3_ODT_335_Hek1055_read_count
# isonum
# iso1187                             1187498
#
# [1 rows x 33 columns]

# %%
satbls = ! ls /nfs/turbo/umms-kitzmanj/oldvol2/jacob/proj/jensplice/20220426_wt1_subasm_filter_stringent/sapipe/sa/*.haps.all.txt

# %%
satbl_fn = { sa.split( '/')[ -1 ].split( '.' )[ 0 ]: pd.read_table( sa ).set_index( 'readgroupid' ) for sa in satbls }

# %%
for lib in satbl_fn.keys():
    
    satbl_fn[ lib ] = satbl_fn[ lib ][ [ col for col in satbl_fn[ lib ] if not col.startswith( 'nbp_' ) ] ].copy()

# %%
exonbed = pbt.BedTool( '/nfs/kitzman2/smithcat/proj/wt1_2022/refs/wt1_ex9.bed' )

# %%
isos = jn.make_junction_graph( exonbed )

# %%
isos
# Out:
# {'iso00': ((650, 696), (1267, 1350), (3479, 3533)),
#  'iso01': ((650, 696), (1267, 1359), (3479, 3533)),
#  'iso02': ((650, 696), (3479, 3533))}

# %%
unique_jns = list( { jn for grp,jn_tups in isos.items() for jn_tup in jn_tups for jn in jn_tup
                       if 696 < jn < 3479 } )

# %%
unique_jns
# Out:
# [1267, 1350, 1359]

# %%
msamp_rnabam = { samp : pysam.AlignmentFile( msamp_fn[ samp ], 'rb' ) for samp in msamp_fn }

# %%
for lib in satbl_fn:
    
    print( lib )
    
    print( satbl_fn[ lib ].head() )

# %%
# %%time
#18 min/sample

iso_df_stats = { lib: jn.summarize_isos_by_var_bc_pe( { samp: bam for samp,bam in msamp_rnabam.items()
                                                        if lib.replace( 'JKP', '' ) in samp },
                                                      [ ( 649, 696 ), ( 3478, 3533 ) ],
                                                      satbl_fn[ lib ],
                                                      isogrp_df,
                                                      unique_jns,
                                                      [ ( ( 1266, 1350 ), ), ( ( 1266, 1359 ), ), () ],
                                                      spl_tol = 3,
                                                      indel_tol = 20,
                                                      min_matches_for = 90,
                                                      min_matches_rev = 70,
                                                      bc_tag = 'BC',
                                                     ) 
                  for lib in satbl_fn }

# %%
for lib in iso_df_stats:
    print( lib, iso_df_stats[ lib ].shape )
# Out:
# JKP1053 (6386, 117)
# JKP1054 (6386, 77)
# JKP1055 (6386, 77)

# %%
for lib in iso_df_stats:
    print( lib, iso_df_stats[ lib ].query( 'total_passfilt > 0' ).shape )
# Out:
# JKP1053 (231, 117)
# JKP1054 (224, 77)
# JKP1055 (257, 77)

# %%
for lib in iso_df_stats:
    print( lib, ( iso_df_stats[ lib ].query( 'total_passfilt == 0' ).total_read_count.sum() / iso_df_stats[ lib ].total_read_count.sum() )*100 )
# Out:
# JKP1053 0.2490599007186634
# JKP1054 0.4206742678143337
# JKP1055 0.4112410690525785

# %%
for lib in iso_df_stats:
    print( lib, ( iso_df_stats[ lib ].query( 'total_passfilt == 0' ).total_num_bcs.sum() / iso_df_stats[ lib ].total_num_bcs.sum() )*100 )
# Out:
# JKP1053 0.3191391206421711
# JKP1054 0.36252133322385294
# JKP1055 0.20012527710218403

# %%
iso_df_stats[ 'JKP1053' ]
# Out:
#                                             isoform  \
# isonum
# iso0000                ((1136, 1225), (1301, 1350))
# iso0001                ((1267, 1290), (1320, 1350))
# iso0002                ((1267, 1314), (1337, 1359))
# iso0003                ((1267, 1282), (1328, 1359))
# iso0004                ((1136, 1224), (1306, 1359))
# ...                                             ...
# iso6381                ((1236, 1242), (1266, 1350))
# iso6382                ((1146, 1222), (1281, 1359))
# iso6383                             ((1284, 1348),)
# iso6384                ((1267, 1354), (3245, 3249))
# iso6385  ((1267, 1306), (1563, 1568), (2040, 2045))
#
#          BB_test_Cos1053_JKLab0340_MM1B_read_count  \
# isonum
# iso0000                                          0
# iso0001                                          0
# iso0002                                          1
# iso0003                                          0
# iso0004                                          0
# ...                                            ...
# iso6381                                          0
# iso6382                                          0
# iso6383                                          0
# iso6384                                          0
# iso6385                                          0
#
#          BB_test_Cos1053_JKLab0340_MM2B_read_count  \
# isonum
# iso0000                                          0
# iso0001                                          0
# iso0002                                        272
# iso0003                                          0
# iso0004                                          0
# ...                                            ...
# iso6381                                          0
# iso6382                                          0
# iso6383                                          1
# iso6384                                          0
# iso6385                                          0
#
#          BB_test_Cos1053_oligodT_MM1B_read_count  \
# isonum
# iso0000                                        0
# iso0001                                        0
# iso0002                                        0
# iso0003                                        2
# iso0004                                        0
# ...                                          ...
# iso6381                                        0
# iso6382                                        0
# iso6383                                        0
# iso6384                                        0
# iso6385                                        0
#
#          BB_test_Cos1053_oligodT_MM2B_read_count  \
# isonum
# iso0000                                        0
# iso0001                                        0
# iso0002                                        0
# iso0003                                        0
# iso0004                                        0
# ...                                          ...
# iso6381                                        0
# iso6382                                        0
# iso6383                                        0
# iso6384                                        0
# iso6385                                        0
#
#          BB_RT_1_340_243_Cos1053_read_count  \
# isonum
# iso0000                                   0
# iso0001                                   0
# iso0002                                   1
# iso0003                                   0
# iso0004                                   0
# ...                                     ...
# iso6381                                   0
# iso6382                                   0
# iso6383                                   0
# iso6384                                   0
# iso6385                                   0
#
#          BB_RT_1_340_243_Hek1053_read_count  \
# isonum
# iso0000                                   0
# iso0001                                   0
# iso0002                                 127
# iso0003                                   0
# iso0004                                   1
# ...                                     ...
# iso6381                                   0
# iso6382                                   3
# iso6383                                   0
# iso6384                                   0
# iso6385                                   0
#
#          BB_RT_1_340_335_Cos1053_read_count  \
# isonum
# iso0000                                   0
# iso0001                                   0
# iso0002                                  64
# iso0003                                   0
# iso0004                                   0
# ...                                     ...
# iso6381                                   0
# iso6382                                   0
# iso6383                                   0
# iso6384                                   0
# iso6385                                   0
#
#          BB_RT_1_340_335_Hek1053_read_count  \
# isonum
# iso0000                                   0
# iso0001                                   0
# iso0002                                  59
# iso0003                                   1
# iso0004                                   0
# ...                                     ...
# iso6381                                   0
# iso6382                                   0
# iso6383                                   0
# iso6384                                   0
# iso6385                                   0
#
#          BB_RT_1b_340_243_Hek1053_read_count  ...  \
# isonum                                        ...
# iso0000                                    0  ...
# iso0001                                    0  ...
# iso0002                                  140  ...
# iso0003                                    0  ...
# iso0004                                    2  ...
# ...                                      ...  ...
# iso6381                                    1  ...
# iso6382                                    3  ...
# iso6383                                    0  ...
# iso6384                                    0  ...
# iso6385                                    0  ...
#
#          BB_RT_1_ODT_335_Cos1053_filter  BB_RT_1_ODT_335_Hek1053_num_bcs  \
# isonum
# iso0000                             0.0                              0.0
# iso0001                             0.0                              0.0
# iso0002                             0.0                             10.0
# iso0003                             0.0                              0.0
# iso0004                             0.0                              0.0
# ...                                 ...                              ...
# iso6381                             0.0                              0.0
# iso6382                             0.0                              0.0
# iso6383                             0.0                              0.0
# iso6384                             0.0                              0.0
# iso6385                             0.0                              0.0
#
#          BB_RT_1_ODT_335_Hek1053_num_vars  \
# isonum
# iso0000                               0.0
# iso0001                               0.0
# iso0002                               6.0
# iso0003                               0.0
# iso0004                               0.0
# ...                                   ...
# iso6381                               0.0
# iso6382                               0.0
# iso6383                               0.0
# iso6384                               0.0
# iso6385                               0.0
#
#          BB_RT_1_ODT_335_Hek1053_max_reads_per_bc  \
# isonum
# iso0000                                       0.0
# iso0001                                       0.0
# iso0002                                       7.0
# iso0003                                       0.0
# iso0004                                       0.0
# ...                                           ...
# iso6381                                       0.0
# iso6382                                       0.0
# iso6383                                       0.0
# iso6384                                       0.0
# iso6385                                       0.0
#
#          BB_RT_1_ODT_335_Hek1053_max_bc_per_var  \
# isonum
# iso0000                                     0.0
# iso0001                                     0.0
# iso0002                                     5.0
# iso0003                                     0.0
# iso0004                                     0.0
# ...                                         ...
# iso6381                                     0.0
# iso6382                                     0.0
# iso6383                                     0.0
# iso6384                                     0.0
# iso6385                                     0.0
#
#          BB_RT_1_ODT_335_Hek1053_filter  total_read_count  total_num_bcs  \
# isonum
# iso0000                             0.0                 3            1.0
# iso0001                             0.0                 2            1.0
# iso0002                             3.0              1105          170.0
# iso0003                             0.0                11            2.0
# iso0004                             0.0                 4            1.0
# ...                                 ...               ...            ...
# iso6381                             0.0                 1            1.0
# iso6382                             0.0                12            1.0
# iso6383                             0.0                 3            1.0
# iso6384                             0.0                 1            0.0
# iso6385                             0.0                 4            0.0
#
#          total_num_vars  total_passfilt
# isonum
# iso0000             1.0               0
# iso0001             1.0               0
# iso0002           129.0               9
# iso0003             2.0               0
# iso0004             1.0               0
# ...                 ...             ...
# iso6381             1.0               0
# iso6382             1.0               0
# iso6383             1.0               0
# iso6384             0.0               0
# iso6385             0.0               0
#
# [6386 rows x 117 columns]

# %%
bdout = '/nfs/kitzman2/smithcat/proj/wt1_2022/ex9_data/'

# %%
for lib in iso_df_stats.keys():    
    iso_df_stats[ lib ].reset_index().to_csv( bdout + 'wt1_ex9_%s_isoforms_2022-0514.txt' % lib,
                                               sep = '\t',
                                               index = False )

# %%
iso_df_stats_all = iso_df_stats[ 'JKP1053' ].merge( iso_df_stats[ 'JKP1054' ],
                                                    left_index = True,
                                                    right_index = True,
                                                    how = 'outer',
                                                    suffixes = ( '_JKP1053', '_JKP1054' )
                                                  )

# %%
iso_df_stats_all
# Out:
#                                     isoform_JKP1053  \
# isonum
# iso0000                ((1136, 1225), (1301, 1350))
# iso0001                ((1267, 1290), (1320, 1350))
# iso0002                ((1267, 1314), (1337, 1359))
# iso0003                ((1267, 1282), (1328, 1359))
# iso0004                ((1136, 1224), (1306, 1359))
# ...                                             ...
# iso6381                ((1236, 1242), (1266, 1350))
# iso6382                ((1146, 1222), (1281, 1359))
# iso6383                             ((1284, 1348),)
# iso6384                ((1267, 1354), (3245, 3249))
# iso6385  ((1267, 1306), (1563, 1568), (2040, 2045))
#
#          BB_test_Cos1053_JKLab0340_MM1B_read_count_JKP1053  \
# isonum
# iso0000                                                  0
# iso0001                                                  0
# iso0002                                                  1
# iso0003                                                  0
# iso0004                                                  0
# ...                                                    ...
# iso6381                                                  0
# iso6382                                                  0
# iso6383                                                  0
# iso6384                                                  0
# iso6385                                                  0
#
#          BB_test_Cos1053_JKLab0340_MM2B_read_count_JKP1053  \
# isonum
# iso0000                                                  0
# iso0001                                                  0
# iso0002                                                272
# iso0003                                                  0
# iso0004                                                  0
# ...                                                    ...
# iso6381                                                  0
# iso6382                                                  0
# iso6383                                                  1
# iso6384                                                  0
# iso6385                                                  0
#
#          BB_test_Cos1053_oligodT_MM1B_read_count_JKP1053  \
# isonum
# iso0000                                                0
# iso0001                                                0
# iso0002                                                0
# iso0003                                                2
# iso0004                                                0
# ...                                                  ...
# iso6381                                                0
# iso6382                                                0
# iso6383                                                0
# iso6384                                                0
# iso6385                                                0
#
#          BB_test_Cos1053_oligodT_MM2B_read_count_JKP1053  \
# isonum
# iso0000                                                0
# iso0001                                                0
# iso0002                                                0
# iso0003                                                0
# iso0004                                                0
# ...                                                  ...
# iso6381                                                0
# iso6382                                                0
# iso6383                                                0
# iso6384                                                0
# iso6385                                                0
#
#          BB_RT_1_340_243_Cos1053_read_count_JKP1053  \
# isonum
# iso0000                                           0
# iso0001                                           0
# iso0002                                           1
# iso0003                                           0
# iso0004                                           0
# ...                                             ...
# iso6381                                           0
# iso6382                                           0
# iso6383                                           0
# iso6384                                           0
# iso6385                                           0
#
#          BB_RT_1_340_243_Hek1053_read_count_JKP1053  \
# isonum
# iso0000                                           0
# iso0001                                           0
# iso0002                                         127
# iso0003                                           0
# iso0004                                           1
# ...                                             ...
# iso6381                                           0
# iso6382                                           3
# iso6383                                           0
# iso6384                                           0
# iso6385                                           0
#
#          BB_RT_1_340_335_Cos1053_read_count_JKP1053  \
# isonum
# iso0000                                           0
# iso0001                                           0
# iso0002                                          64
# iso0003                                           0
# iso0004                                           0
# ...                                             ...
# iso6381                                           0
# iso6382                                           0
# iso6383                                           0
# iso6384                                           0
# iso6385                                           0
#
#          BB_RT_1_340_335_Hek1053_read_count_JKP1053  \
# isonum
# iso0000                                           0
# iso0001                                           0
# iso0002                                          59
# iso0003                                           1
# iso0004                                           0
# ...                                             ...
# iso6381                                           0
# iso6382                                           0
# iso6383                                           0
# iso6384                                           0
# iso6385                                           0
#
#          BB_RT_1b_340_243_Hek1053_read_count_JKP1053  ...  \
# isonum                                                ...
# iso0000                                            0  ...
# iso0001                                            0  ...
# iso0002                                          140  ...
# iso0003                                            0  ...
# iso0004                                            2  ...
# ...                                              ...  ...
# iso6381                                            1  ...
# iso6382                                            3  ...
# iso6383                                            0  ...
# iso6384                                            0  ...
# iso6385                                            0  ...
#
#          BB_RT_3_ODT_335_Hek1055_max_bc_per_var  \
# isonum
# iso0000                                     0.0
# iso0001                                     0.0
# iso0002                                     0.0
# iso0003                                     0.0
# iso0004                                     0.0
# ...                                         ...
# iso6381                                     0.0
# iso6382                                     0.0
# iso6383                                     1.0
# iso6384                                     0.0
# iso6385                                     0.0
#
#          BB_RT_3_ODT_335_Hek1055_filter  total_read_count_JKP1055  \
# isonum
# iso0000                             0.0                         3
# iso0001                             0.0                         2
# iso0002                             0.0                      1105
# iso0003                             0.0                        11
# iso0004                             0.0                         4
# ...                                 ...                       ...
# iso6381                             0.0                         1
# iso6382                             0.0                        12
# iso6383                             0.0                         3
# iso6384                             0.0                         1
# iso6385                             0.0                         4
#
#          total_num_bcs_JKP1055  total_num_vars_JKP1055  \
# isonum
# iso0000                    0.0                     0.0
# iso0001                    0.0                     0.0
# iso0002                    0.0                     0.0
# iso0003                    0.0                     0.0
# iso0004                    0.0                     0.0
# ...                        ...                     ...
# iso6381                    0.0                     0.0
# iso6382                    0.0                     0.0
# iso6383                    1.0                     1.0
# iso6384                    1.0                     1.0
# iso6385                    1.0                     1.0
#
#          total_passfilt_JKP1055  total_read_count  total_num_bcs  \
# isonum
# iso0000                       0                 9            1.0
# iso0001                       0                 6            1.0
# iso0002                       0              3315          170.0
# iso0003                       0                33            2.0
# iso0004                       0                12            1.0
# ...                         ...               ...            ...
# iso6381                       0                 3            1.0
# iso6382                       0                36            1.0
# iso6383                       0                 9            2.0
# iso6384                       0                 3            1.0
# iso6385                       0                12            1.0
#
#          total_num_vars  total_passfilt
# isonum
# iso0000             1.0               0
# iso0001             1.0               0
# iso0002           129.0               9
# iso0003             2.0               0
# iso0004             1.0               0
# ...                 ...             ...
# iso6381             1.0               0
# iso6382             1.0               0
# iso6383             2.0               0
# iso6384             1.0               0
# iso6385             1.0               0
#
# [6386 rows x 275 columns]

# %%
iso_df_stats_all = iso_df_stats_all.merge( iso_df_stats[ 'JKP1055' ].rename( columns = { col: col + '_JKP1055' 
                                                                                         for col in iso_df_stats[ 'JKP1055' ] if col.startswith( 'total_' ) } ),
                                            left_index = True,
                                            right_index = True,
                                            how = 'outer',
                                            suffixes = ( '', '_JKP1055' )
                                        )

# %%
total_cols = [ 'total_read_count', 'total_num_bcs', 'total_num_vars', 'total_passfilt' ]

for col in total_cols:
    
    iso_df_stats_all[ col ] = iso_df_stats_all[ [ lcol for lcol in iso_df_stats_all if col + '_' in lcol ] ].sum( axis = 1 )

# %%
len( bam )
# Out:
# 32

# %%
iso_df_stats_all.shape
# Out:
# (6386, 275)

# %%
iso_df_stats_all.query( 'total_passfilt > 0' ).shape
# Out:
# (431, 275)

# %%
iso_df_stats_all.query( 'total_passfilt >= 16' ).shape
# Out:
# (66, 275)

# %%
( iso_df_stats_all.query( 'total_passfilt == 0' ).total_read_count.sum() / iso_df_stats_all.total_read_count.sum() )*100
# Out:
# 0.11385525052641854

# %%
( iso_df_stats_all.query( 'total_passfilt >= 16' ).total_read_count.sum() / iso_df_stats_all.total_read_count.sum() )*100
# Out:
# 99.47733909593774

# %%
( iso_df_stats_all.query( 'total_passfilt == 0' ).total_num_bcs.sum() / iso_df_stats_all.total_num_bcs.sum() )*100
# Out:
# 0.2220691058447506

# %%
( iso_df_stats_all.query( 'total_passfilt >= 16' ).total_num_bcs.sum() / iso_df_stats_all.total_num_bcs.sum() )*100
# Out:
# 99.06743856722191

# %%
iso_df_stats_all.total_num_bcs.isnull().sum()
# Out:
# 0

# %%
iso_df_stats_all.reset_index().to_csv( bdout + 'wt1_ex9_isoforms_2022-0514.txt',
                                               sep = '\t',
                                               index = False )
