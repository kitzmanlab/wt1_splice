# %%
import pybedtools as pbt
import pysam
import pandas as pd
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt

# %%
import os.path as op

# %%
import splanl.junction_scorer as jn
import splanl.merge_bcs as mbcs
import splanl.coords as coords
import splanl.plots as sp
import splanl.score_motifs as sm
import splanl.inspect_variants as iv
import splanl.post_processing as pp
# Out:
# Using TensorFlow backend.

# %%
fa_file = '/nfs/kitzman2/jacob/proj/jensplice/20220415_wt1_mpsa_trial3/jkp1053_1054_1055.fa'

# %%
refseq = pp.get_refseq( fa_file )

# %%
bam1 = ! ls /nfs/kitzman2/jacob/proj/jensplice/20220513_wt1_mpsa_trial4and3_deep_redoAligns/process_star/BB_test*/*out.wbcs.bam

# %%
bam2 = ! ls /nfs/kitzman2/jacob/proj/jensplice/20220513_wt1_mpsa_trial4and3_deep_redoAligns/process_star/BB_RT*/*out.wbcs.bam

# %%
bam1
# Out:
# ['/nfs/kitzman2/jacob/proj/jensplice/20220513_wt1_mpsa_trial4and3_deep_redoAligns/process_star/BB_test_Cos1053_JKLab0340_MM1B/BB_test_Cos1053_JKLab0340_MM1BAligned.out.wbcs.bam',
#  '/nfs/kitzman2/jacob/proj/jensplice/20220513_wt1_mpsa_trial4and3_deep_redoAligns/process_star/BB_test_Cos1053_JKLab0340_MM2B/BB_test_Cos1053_JKLab0340_MM2BAligned.out.wbcs.bam',
#  '/nfs/kitzman2/jacob/proj/jensplice/20220513_wt1_mpsa_trial4and3_deep_redoAligns/process_star/BB_test_Cos1053_oligodT_MM1B/BB_test_Cos1053_oligodT_MM1BAligned.out.wbcs.bam',
#  '/nfs/kitzman2/jacob/proj/jensplice/20220513_wt1_mpsa_trial4and3_deep_redoAligns/process_star/BB_test_Cos1053_oligodT_MM2B/BB_test_Cos1053_oligodT_MM2BAligned.out.wbcs.bam']

# %%
bam2
# Out:
# ['/nfs/kitzman2/jacob/proj/jensplice/20220513_wt1_mpsa_trial4and3_deep_redoAligns/process_star/BB_RT_1_340_243_Cos1053/BB_RT_1_340_243_Cos1053Aligned.out.wbcs.bam',
#  '/nfs/kitzman2/jacob/proj/jensplice/20220513_wt1_mpsa_trial4and3_deep_redoAligns/process_star/BB_RT_1_340_243_Hek1053/BB_RT_1_340_243_Hek1053Aligned.out.wbcs.bam',
#  '/nfs/kitzman2/jacob/proj/jensplice/20220513_wt1_mpsa_trial4and3_deep_redoAligns/process_star/BB_RT_1_340_335_Cos1053/BB_RT_1_340_335_Cos1053Aligned.out.wbcs.bam',
#  '/nfs/kitzman2/jacob/proj/jensplice/20220513_wt1_mpsa_trial4and3_deep_redoAligns/process_star/BB_RT_1_340_335_Hek1053/BB_RT_1_340_335_Hek1053Aligned.out.wbcs.bam',
#  '/nfs/kitzman2/jacob/proj/jensplice/20220513_wt1_mpsa_trial4and3_deep_redoAligns/process_star/BB_RT_1b_340_243_Hek1053/BB_RT_1b_340_243_Hek1053Aligned.out.wbcs.bam',
#  '/nfs/kitzman2/jacob/proj/jensplice/20220513_wt1_mpsa_trial4and3_deep_redoAligns/process_star/BB_RT_1b_340_335_Hek1053/BB_RT_1b_340_335_Hek1053Aligned.out.wbcs.bam',
#  '/nfs/kitzman2/jacob/proj/jensplice/20220513_wt1_mpsa_trial4and3_deep_redoAligns/process_star/BB_RT_1b_ODT_243_Hek1053/BB_RT_1b_ODT_243_Hek1053Aligned.out.wbcs.bam',
#  '/nfs/kitzman2/jacob/proj/jensplice/20220513_wt1_mpsa_trial4and3_deep_redoAligns/process_star/BB_RT_1b_ODT_335_Hek1053/BB_RT_1b_ODT_335_Hek1053Aligned.out.wbcs.bam',
#  '/nfs/kitzman2/jacob/proj/jensplice/20220513_wt1_mpsa_trial4and3_deep_redoAligns/process_star/BB_RT_1_ODT_243_Cos1053/BB_RT_1_ODT_243_Cos1053Aligned.out.wbcs.bam',
#  '/nfs/kitzman2/jacob/proj/jensplice/20220513_wt1_mpsa_trial4and3_deep_redoAligns/process_star/BB_RT_1_ODT_243_Hek1053/BB_RT_1_ODT_243_Hek1053Aligned.out.wbcs.bam',
#  '/nfs/kitzman2/jacob/proj/jensplice/20220513_wt1_mpsa_trial4and3_deep_redoAligns/process_star/BB_RT_1_ODT_335_Cos1053/BB_RT_1_ODT_335_Cos1053Aligned.out.wbcs.bam',
#  '/nfs/kitzman2/jacob/proj/jensplice/20220513_wt1_mpsa_trial4and3_deep_redoAligns/process_star/BB_RT_1_ODT_335_Hek1053/BB_RT_1_ODT_335_Hek1053Aligned.out.wbcs.bam',
#  '/nfs/kitzman2/jacob/proj/jensplice/20220513_wt1_mpsa_trial4and3_deep_redoAligns/process_star/BB_RT_2_340_243_Cos1054/BB_RT_2_340_243_Cos1054Aligned.out.wbcs.bam',
#  '/nfs/kitzman2/jacob/proj/jensplice/20220513_wt1_mpsa_trial4and3_deep_redoAligns/process_star/BB_RT_2_340_243_Hek1054/BB_RT_2_340_243_Hek1054Aligned.out.wbcs.bam',
#  '/nfs/kitzman2/jacob/proj/jensplice/20220513_wt1_mpsa_trial4and3_deep_redoAligns/process_star/BB_RT_2_340_335_Cos1054/BB_RT_2_340_335_Cos1054Aligned.out.wbcs.bam',
#  '/nfs/kitzman2/jacob/proj/jensplice/20220513_wt1_mpsa_trial4and3_deep_redoAligns/process_star/BB_RT_2_340_335_Hek1054/BB_RT_2_340_335_Hek1054Aligned.out.wbcs.bam',
#  '/nfs/kitzman2/jacob/proj/jensplice/20220513_wt1_mpsa_trial4and3_deep_redoAligns/process_star/BB_RT_2_ODT_243_Cos1054/BB_RT_2_ODT_243_Cos1054Aligned.out.wbcs.bam',
#  '/nfs/kitzman2/jacob/proj/jensplice/20220513_wt1_mpsa_trial4and3_deep_redoAligns/process_star/BB_RT_2_ODT_243_Hek1054/BB_RT_2_ODT_243_Hek1054Aligned.out.wbcs.bam',
#  '/nfs/kitzman2/jacob/proj/jensplice/20220513_wt1_mpsa_trial4and3_deep_redoAligns/process_star/BB_RT_2_ODT_335_Cos1054/BB_RT_2_ODT_335_Cos1054Aligned.out.wbcs.bam',
#  '/nfs/kitzman2/jacob/proj/jensplice/20220513_wt1_mpsa_trial4and3_deep_redoAligns/process_star/BB_RT_2_ODT_335_Hek1054/BB_RT_2_ODT_335_Hek1054Aligned.out.wbcs.bam',
#  '/nfs/kitzman2/jacob/proj/jensplice/20220513_wt1_mpsa_trial4and3_deep_redoAligns/process_star/BB_RT_3_340_243_Cos1055/BB_RT_3_340_243_Cos1055Aligned.out.wbcs.bam',
#  '/nfs/kitzman2/jacob/proj/jensplice/20220513_wt1_mpsa_trial4and3_deep_redoAligns/process_star/BB_RT_3_340_243_Hek1055/BB_RT_3_340_243_Hek1055Aligned.out.wbcs.bam',
#  '/nfs/kitzman2/jacob/proj/jensplice/20220513_wt1_mpsa_trial4and3_deep_redoAligns/process_star/BB_RT_3_340_335_Cos1055/BB_RT_3_340_335_Cos1055Aligned.out.wbcs.bam',
#  '/nfs/kitzman2/jacob/proj/jensplice/20220513_wt1_mpsa_trial4and3_deep_redoAligns/process_star/BB_RT_3_340_335_Hek1055/BB_RT_3_340_335_Hek1055Aligned.out.wbcs.bam',
#  '/nfs/kitzman2/jacob/proj/jensplice/20220513_wt1_mpsa_trial4and3_deep_redoAligns/process_star/BB_RT_3_ODT_243_Cos1055/BB_RT_3_ODT_243_Cos1055Aligned.out.wbcs.bam',
#  '/nfs/kitzman2/jacob/proj/jensplice/20220513_wt1_mpsa_trial4and3_deep_redoAligns/process_star/BB_RT_3_ODT_243_Hek1055/BB_RT_3_ODT_243_Hek1055Aligned.out.wbcs.bam',
#  '/nfs/kitzman2/jacob/proj/jensplice/20220513_wt1_mpsa_trial4and3_deep_redoAligns/process_star/BB_RT_3_ODT_335_cos1055/BB_RT_3_ODT_335_cos1055Aligned.out.wbcs.bam',
#  '/nfs/kitzman2/jacob/proj/jensplice/20220513_wt1_mpsa_trial4and3_deep_redoAligns/process_star/BB_RT_3_ODT_335_Hek1055/BB_RT_3_ODT_335_Hek1055Aligned.out.wbcs.bam']

# %%
bam = bam1 + bam2

# %%
len( bam )
# Out:
# 32

# %%
msamp_fn = { b.split( '/')[ -1 ].split( '.' )[ 0 ].replace( 'Aligned', '' ) : b for b in bam }

# %%
msamp_fn
# Out:
# {'BB_test_Cos1053_JKLab0340_MM1B': '/nfs/kitzman2/jacob/proj/jensplice/20220513_wt1_mpsa_trial4and3_deep_redoAligns/process_star/BB_test_Cos1053_JKLab0340_MM1B/BB_test_Cos1053_JKLab0340_MM1BAligned.out.wbcs.bam',
#  'BB_test_Cos1053_JKLab0340_MM2B': '/nfs/kitzman2/jacob/proj/jensplice/20220513_wt1_mpsa_trial4and3_deep_redoAligns/process_star/BB_test_Cos1053_JKLab0340_MM2B/BB_test_Cos1053_JKLab0340_MM2BAligned.out.wbcs.bam',
#  'BB_test_Cos1053_oligodT_MM1B': '/nfs/kitzman2/jacob/proj/jensplice/20220513_wt1_mpsa_trial4and3_deep_redoAligns/process_star/BB_test_Cos1053_oligodT_MM1B/BB_test_Cos1053_oligodT_MM1BAligned.out.wbcs.bam',
#  'BB_test_Cos1053_oligodT_MM2B': '/nfs/kitzman2/jacob/proj/jensplice/20220513_wt1_mpsa_trial4and3_deep_redoAligns/process_star/BB_test_Cos1053_oligodT_MM2B/BB_test_Cos1053_oligodT_MM2BAligned.out.wbcs.bam',
#  'BB_RT_1_340_243_Cos1053': '/nfs/kitzman2/jacob/proj/jensplice/20220513_wt1_mpsa_trial4and3_deep_redoAligns/process_star/BB_RT_1_340_243_Cos1053/BB_RT_1_340_243_Cos1053Aligned.out.wbcs.bam',
#  'BB_RT_1_340_243_Hek1053': '/nfs/kitzman2/jacob/proj/jensplice/20220513_wt1_mpsa_trial4and3_deep_redoAligns/process_star/BB_RT_1_340_243_Hek1053/BB_RT_1_340_243_Hek1053Aligned.out.wbcs.bam',
#  'BB_RT_1_340_335_Cos1053': '/nfs/kitzman2/jacob/proj/jensplice/20220513_wt1_mpsa_trial4and3_deep_redoAligns/process_star/BB_RT_1_340_335_Cos1053/BB_RT_1_340_335_Cos1053Aligned.out.wbcs.bam',
#  'BB_RT_1_340_335_Hek1053': '/nfs/kitzman2/jacob/proj/jensplice/20220513_wt1_mpsa_trial4and3_deep_redoAligns/process_star/BB_RT_1_340_335_Hek1053/BB_RT_1_340_335_Hek1053Aligned.out.wbcs.bam',
#  'BB_RT_1b_340_243_Hek1053': '/nfs/kitzman2/jacob/proj/jensplice/20220513_wt1_mpsa_trial4and3_deep_redoAligns/process_star/BB_RT_1b_340_243_Hek1053/BB_RT_1b_340_243_Hek1053Aligned.out.wbcs.bam',
#  'BB_RT_1b_340_335_Hek1053': '/nfs/kitzman2/jacob/proj/jensplice/20220513_wt1_mpsa_trial4and3_deep_redoAligns/process_star/BB_RT_1b_340_335_Hek1053/BB_RT_1b_340_335_Hek1053Aligned.out.wbcs.bam',
#  'BB_RT_1b_ODT_243_Hek1053': '/nfs/kitzman2/jacob/proj/jensplice/20220513_wt1_mpsa_trial4and3_deep_redoAligns/process_star/BB_RT_1b_ODT_243_Hek1053/BB_RT_1b_ODT_243_Hek1053Aligned.out.wbcs.bam',
#  'BB_RT_1b_ODT_335_Hek1053': '/nfs/kitzman2/jacob/proj/jensplice/20220513_wt1_mpsa_trial4and3_deep_redoAligns/process_star/BB_RT_1b_ODT_335_Hek1053/BB_RT_1b_ODT_335_Hek1053Aligned.out.wbcs.bam',
#  'BB_RT_1_ODT_243_Cos1053': '/nfs/kitzman2/jacob/proj/jensplice/20220513_wt1_mpsa_trial4and3_deep_redoAligns/process_star/BB_RT_1_ODT_243_Cos1053/BB_RT_1_ODT_243_Cos1053Aligned.out.wbcs.bam',
#  'BB_RT_1_ODT_243_Hek1053': '/nfs/kitzman2/jacob/proj/jensplice/20220513_wt1_mpsa_trial4and3_deep_redoAligns/process_star/BB_RT_1_ODT_243_Hek1053/BB_RT_1_ODT_243_Hek1053Aligned.out.wbcs.bam',
#  'BB_RT_1_ODT_335_Cos1053': '/nfs/kitzman2/jacob/proj/jensplice/20220513_wt1_mpsa_trial4and3_deep_redoAligns/process_star/BB_RT_1_ODT_335_Cos1053/BB_RT_1_ODT_335_Cos1053Aligned.out.wbcs.bam',
#  'BB_RT_1_ODT_335_Hek1053': '/nfs/kitzman2/jacob/proj/jensplice/20220513_wt1_mpsa_trial4and3_deep_redoAligns/process_star/BB_RT_1_ODT_335_Hek1053/BB_RT_1_ODT_335_Hek1053Aligned.out.wbcs.bam',
#  'BB_RT_2_340_243_Cos1054': '/nfs/kitzman2/jacob/proj/jensplice/20220513_wt1_mpsa_trial4and3_deep_redoAligns/process_star/BB_RT_2_340_243_Cos1054/BB_RT_2_340_243_Cos1054Aligned.out.wbcs.bam',
#  'BB_RT_2_340_243_Hek1054': '/nfs/kitzman2/jacob/proj/jensplice/20220513_wt1_mpsa_trial4and3_deep_redoAligns/process_star/BB_RT_2_340_243_Hek1054/BB_RT_2_340_243_Hek1054Aligned.out.wbcs.bam',
#  'BB_RT_2_340_335_Cos1054': '/nfs/kitzman2/jacob/proj/jensplice/20220513_wt1_mpsa_trial4and3_deep_redoAligns/process_star/BB_RT_2_340_335_Cos1054/BB_RT_2_340_335_Cos1054Aligned.out.wbcs.bam',
#  'BB_RT_2_340_335_Hek1054': '/nfs/kitzman2/jacob/proj/jensplice/20220513_wt1_mpsa_trial4and3_deep_redoAligns/process_star/BB_RT_2_340_335_Hek1054/BB_RT_2_340_335_Hek1054Aligned.out.wbcs.bam',
#  'BB_RT_2_ODT_243_Cos1054': '/nfs/kitzman2/jacob/proj/jensplice/20220513_wt1_mpsa_trial4and3_deep_redoAligns/process_star/BB_RT_2_ODT_243_Cos1054/BB_RT_2_ODT_243_Cos1054Aligned.out.wbcs.bam',
#  'BB_RT_2_ODT_243_Hek1054': '/nfs/kitzman2/jacob/proj/jensplice/20220513_wt1_mpsa_trial4and3_deep_redoAligns/process_star/BB_RT_2_ODT_243_Hek1054/BB_RT_2_ODT_243_Hek1054Aligned.out.wbcs.bam',
#  'BB_RT_2_ODT_335_Cos1054': '/nfs/kitzman2/jacob/proj/jensplice/20220513_wt1_mpsa_trial4and3_deep_redoAligns/process_star/BB_RT_2_ODT_335_Cos1054/BB_RT_2_ODT_335_Cos1054Aligned.out.wbcs.bam',
#  'BB_RT_2_ODT_335_Hek1054': '/nfs/kitzman2/jacob/proj/jensplice/20220513_wt1_mpsa_trial4and3_deep_redoAligns/process_star/BB_RT_2_ODT_335_Hek1054/BB_RT_2_ODT_335_Hek1054Aligned.out.wbcs.bam',
#  'BB_RT_3_340_243_Cos1055': '/nfs/kitzman2/jacob/proj/jensplice/20220513_wt1_mpsa_trial4and3_deep_redoAligns/process_star/BB_RT_3_340_243_Cos1055/BB_RT_3_340_243_Cos1055Aligned.out.wbcs.bam',
#  'BB_RT_3_340_243_Hek1055': '/nfs/kitzman2/jacob/proj/jensplice/20220513_wt1_mpsa_trial4and3_deep_redoAligns/process_star/BB_RT_3_340_243_Hek1055/BB_RT_3_340_243_Hek1055Aligned.out.wbcs.bam',
#  'BB_RT_3_340_335_Cos1055': '/nfs/kitzman2/jacob/proj/jensplice/20220513_wt1_mpsa_trial4and3_deep_redoAligns/process_star/BB_RT_3_340_335_Cos1055/BB_RT_3_340_335_Cos1055Aligned.out.wbcs.bam',
#  'BB_RT_3_340_335_Hek1055': '/nfs/kitzman2/jacob/proj/jensplice/20220513_wt1_mpsa_trial4and3_deep_redoAligns/process_star/BB_RT_3_340_335_Hek1055/BB_RT_3_340_335_Hek1055Aligned.out.wbcs.bam',
#  'BB_RT_3_ODT_243_Cos1055': '/nfs/kitzman2/jacob/proj/jensplice/20220513_wt1_mpsa_trial4and3_deep_redoAligns/process_star/BB_RT_3_ODT_243_Cos1055/BB_RT_3_ODT_243_Cos1055Aligned.out.wbcs.bam',
#  'BB_RT_3_ODT_243_Hek1055': '/nfs/kitzman2/jacob/proj/jensplice/20220513_wt1_mpsa_trial4and3_deep_redoAligns/process_star/BB_RT_3_ODT_243_Hek1055/BB_RT_3_ODT_243_Hek1055Aligned.out.wbcs.bam',
#  'BB_RT_3_ODT_335_cos1055': '/nfs/kitzman2/jacob/proj/jensplice/20220513_wt1_mpsa_trial4and3_deep_redoAligns/process_star/BB_RT_3_ODT_335_cos1055/BB_RT_3_ODT_335_cos1055Aligned.out.wbcs.bam',
#  'BB_RT_3_ODT_335_Hek1055': '/nfs/kitzman2/jacob/proj/jensplice/20220513_wt1_mpsa_trial4and3_deep_redoAligns/process_star/BB_RT_3_ODT_335_Hek1055/BB_RT_3_ODT_335_Hek1055Aligned.out.wbcs.bam'}

# %%
msamp_rnabam = { samp: pysam.AlignmentFile( msamp_fn[ samp ], 'rb' ) for samp in msamp_fn }

# %%
# %%time
#Ugh stop messing with the min_matches thresholds you are wasting so much time
#keep them here for other exons please and thanks
#you keep losing skips
isos_dfs = { samp: jn.get_all_isoforms_pe( msamp_rnabam[ samp ],
                                           [ ( 649, 696 ), ( 3478, 3533 ) ],
                                            spl_tol = 3,
                                            indel_tol = 20,
                                            min_matches_for = 70,
                                            min_matches_rev = 50 )
             for samp in msamp_rnabam }
# Out:
# CPU times: user 37min 21s, sys: 12.3 s, total: 37min 34s
# Wall time: 37min 34s

# %%
for samp in isos_dfs.keys():
    
    print( samp )
    
    print( isos_dfs[ samp ].head() )
# Out:
# BB_test_Cos1053_JKLab0340_MM1B
#                  read_count
# isoform
# ((1267, 1359),)     2400975
# ((1267, 1350),)     2202889
# ()                  1143438
# bad_ends              75036
# bad_starts            29333
# BB_test_Cos1053_JKLab0340_MM2B
#                  read_count
# isoform
# ((1267, 1359),)     5054350
# ((1267, 1350),)     4607597
# ()                  2304126
# bad_starts            82378
# bad_ends              59270
# BB_test_Cos1053_oligodT_MM1B
#                  read_count
# isoform
# ((1267, 1359),)     2190614
# ((1267, 1350),)     1962858
# ()                  1061553
# bad_ends              65799
# bad_starts            26372
# BB_test_Cos1053_oligodT_MM2B
#                  read_count
# isoform
# ((1267, 1359),)     6181724
# ((1267, 1350),)     5733661
# ()                  3107707
# bad_starts            86387
# bad_ends              74857
# BB_RT_1_340_243_Cos1053
#                  read_count
# isoform
# ((1267, 1359),)     1852418
# ((1267, 1350),)     1642915
# ()                  1305008
# bad_starts            28018
# bad_ends              25719
# BB_RT_1_340_243_Hek1053
#                  read_count
# isoform
# ((1267, 1359),)     3409650
# ((1267, 1350),)     3029467
# ()                  1854048
# bad_starts            42408
# bad_ends              32106
# BB_RT_1_340_335_Cos1053
#                  read_count
# isoform
# ()                  3692206
# ((1267, 1359),)      499731
# ((1267, 1350),)      457547
# bad_ends              29309
# soft_clipped          29068
# BB_RT_1_340_335_Hek1053
#                  read_count
# isoform
# ()                  5053752
# ((1267, 1359),)     1003786
# ((1267, 1350),)      943894
# bad_ends              35832
# bad_starts            14362
# BB_RT_1b_340_243_Hek1053
#                  read_count
# isoform
# ((1267, 1359),)     3096744
# ((1267, 1350),)     2728074
# ()                  1562129
# bad_starts            36762
# bad_ends              27879
# BB_RT_1b_340_335_Hek1053
#                  read_count
# isoform
# ()                  4607728
# ((1267, 1359),)      915495
# ((1267, 1350),)      856632
# bad_ends              32665
# bad_starts            12373
# BB_RT_1b_ODT_243_Hek1053
#                  read_count
# isoform
# ((1267, 1359),)     2735221
# ((1267, 1350),)     2357626
# ()                  1346748
# bad_starts            33349
# bad_ends              24432
# BB_RT_1b_ODT_335_Hek1053
#                  read_count
# isoform
# ()                  2375761
# ((1267, 1359),)      516886
# ((1267, 1350),)      502617
# bad_ends              20365
# bad_starts             7032
# BB_RT_1_ODT_243_Cos1053
#                  read_count
# isoform
# ((1267, 1359),)     2380734
# ((1267, 1350),)     2075058
# ()                  1826861
# bad_starts            40159
# bad_ends              31107
# BB_RT_1_ODT_243_Hek1053
#                  read_count
# isoform
# ((1267, 1359),)     3552384
# ((1267, 1350),)     3054737
# ()                  1821153
# bad_starts            43769
# bad_ends              32436
# BB_RT_1_ODT_335_Cos1053
#                  read_count
# isoform
# ()                  2065114
# ((1267, 1359),)      248211
# ((1267, 1350),)      226881
# soft_clipped          15489
# bad_ends              14614
# BB_RT_1_ODT_335_Hek1053
#                  read_count
# isoform
# ()                  7128108
# ((1267, 1359),)     1525888
# ((1267, 1350),)     1451571
# bad_ends              60053
# bad_starts            22270
# BB_RT_2_340_243_Cos1054
#                  read_count
# isoform
# ((1267, 1359),)     1507476
# ((1267, 1350),)     1335035
# ()                   535973
# bad_starts            38336
# bad_ends              12397
# BB_RT_2_340_243_Hek1054
#                  read_count
# isoform
# ((1267, 1359),)     2695608
# ((1267, 1350),)     2423874
# ()                   982772
# bad_starts            29133
# bad_ends              21938
# BB_RT_2_340_335_Cos1054
#                  read_count
# isoform
# ()                  1088469
# ((1267, 1359),)      223805
# ((1267, 1350),)      208722
# soft_clipped          25759
# bad_starts             7969
# BB_RT_2_340_335_Hek1054
#                  read_count
# isoform
# ()                  3928844
# ((1267, 1359),)      966794
# ((1267, 1350),)      922268
# bad_ends              28471
# bad_starts            12151
# BB_RT_2_ODT_243_Cos1054
#                  read_count
# isoform
# ((1267, 1359),)     1806749
# ((1267, 1350),)     1609919
# ()                   718147
# bad_starts            45209
# bad_ends              15831
# BB_RT_2_ODT_243_Hek1054
#                  read_count
# isoform
# ((1267, 1359),)     2996004
# ((1267, 1350),)     2641858
# ()                  1105304
# bad_starts            32939
# bad_ends              24100
# BB_RT_2_ODT_335_Cos1054
#                  read_count
# isoform
# ()                   811088
# ((1267, 1359),)      148022
# ((1267, 1350),)      132018
# soft_clipped          15860
# bad_starts             5351
# BB_RT_2_ODT_335_Hek1054
#                  read_count
# isoform
# ()                  2751065
# ((1267, 1359),)      670847
# ((1267, 1350),)      644707
# bad_ends              21889
# bad_starts             8429
# BB_RT_3_340_243_Cos1055
#                  read_count
# isoform
# ((1267, 1359),)      935423
# ((1267, 1350),)      854764
# ()                   380082
# bad_starts            12788
# bad_ends               8955
# BB_RT_3_340_243_Hek1055
#                  read_count
# isoform
# ((1267, 1359),)     2235303
# ((1267, 1350),)     1928910
# ()                   627476
# bad_starts            21994
# bad_ends              17004
# BB_RT_3_340_335_Cos1055
#                  read_count
# isoform
# ()                  3547722
# ((1267, 1359),)      642084
# ((1267, 1350),)      607919
# bad_ends              24251
# bad_starts            11059
# BB_RT_3_340_335_Hek1055
#                  read_count
# isoform
# ()                  3917999
# ((1267, 1350),)     1469642
# ((1267, 1359),)     1424797
# bad_ends              39378
# bad_starts            18278
# BB_RT_3_ODT_243_Cos1055
#                  read_count
# isoform
# ((1267, 1359),)     2636654
# ((1267, 1350),)     2365654
# ()                  1467939
# bad_starts            36807
# bad_ends              27053
# BB_RT_3_ODT_243_Hek1055
#                  read_count
# isoform
# ((1267, 1359),)     1605049
# ((1267, 1350),)     1373452
# ()                   461348
# bad_starts            16076
# bad_ends              12469
# BB_RT_3_ODT_335_cos1055
#                  read_count
# isoform
# ()                  4980563
# ((1267, 1359),)      768588
# ((1267, 1350),)      730185
# bad_ends              34790
# bad_starts            13785
# BB_RT_3_ODT_335_Hek1055
#                  read_count
# isoform
# ()                  2568007
# ((1267, 1350),)     1190025
# ((1267, 1359),)     1088778
# bad_ends              32101
# bad_starts            13754

# %%
# %%time
isogrp_df = jn.number_and_merge_isoforms( isos_dfs )
# Out:
# BB_test_Cos1053_JKLab0340_MM1B
# BB_test_Cos1053_JKLab0340_MM2B
# BB_test_Cos1053_oligodT_MM1B
# BB_test_Cos1053_oligodT_MM2B
# BB_RT_1_340_243_Cos1053
# BB_RT_1_340_243_Hek1053
# BB_RT_1_340_335_Cos1053
# BB_RT_1_340_335_Hek1053
# BB_RT_1b_340_243_Hek1053
# BB_RT_1b_340_335_Hek1053
# BB_RT_1b_ODT_243_Hek1053
# BB_RT_1b_ODT_335_Hek1053
# BB_RT_1_ODT_243_Cos1053
# BB_RT_1_ODT_243_Hek1053
# BB_RT_1_ODT_335_Cos1053
# BB_RT_1_ODT_335_Hek1053
# BB_RT_2_340_243_Cos1054
# BB_RT_2_340_243_Hek1054
# BB_RT_2_340_335_Cos1054
# BB_RT_2_340_335_Hek1054
# BB_RT_2_ODT_243_Cos1054
# BB_RT_2_ODT_243_Hek1054
# BB_RT_2_ODT_335_Cos1054
# BB_RT_2_ODT_335_Hek1054
# BB_RT_3_340_243_Cos1055
# BB_RT_3_340_243_Hek1055
# BB_RT_3_340_335_Cos1055
# BB_RT_3_340_335_Hek1055
# BB_RT_3_ODT_243_Cos1055
# BB_RT_3_ODT_243_Hek1055
# BB_RT_3_ODT_335_cos1055
# BB_RT_3_ODT_335_Hek1055
# CPU times: user 19 s, sys: 29 ms, total: 19 s
# Wall time: 19 s

# %%
isogrp_df.head()
# Out:
#                               isoform  \
# isonum
# iso0000  ((1136, 1225), (1301, 1350))
# iso0001  ((1267, 1339), (2660, 2664))
# iso0002  ((1267, 1290), (1320, 1350))
# iso0003  ((1267, 1314), (1337, 1359))
# iso0004  ((1267, 1282), (1328, 1359))
#
#          BB_test_Cos1053_JKLab0340_MM1B_read_count  \
# isonum
# iso0000                                          0
# iso0001                                          0
# iso0002                                          0
# iso0003                                          1
# iso0004                                          0
#
#          BB_test_Cos1053_JKLab0340_MM2B_read_count  \
# isonum
# iso0000                                          0
# iso0001                                          0
# iso0002                                          0
# iso0003                                        273
# iso0004                                          0
#
#          BB_test_Cos1053_oligodT_MM1B_read_count  \
# isonum
# iso0000                                        0
# iso0001                                        0
# iso0002                                        0
# iso0003                                        0
# iso0004                                        2
#
#          BB_test_Cos1053_oligodT_MM2B_read_count  \
# isonum
# iso0000                                        0
# iso0001                                        0
# iso0002                                        0
# iso0003                                        0
# iso0004                                        0
#
#          BB_RT_1_340_243_Cos1053_read_count  \
# isonum
# iso0000                                   0
# iso0001                                   0
# iso0002                                   0
# iso0003                                   1
# iso0004                                   0
#
#          BB_RT_1_340_243_Hek1053_read_count  \
# isonum
# iso0000                                   0
# iso0001                                   0
# iso0002                                   0
# iso0003                                 127
# iso0004                                   0
#
#          BB_RT_1_340_335_Cos1053_read_count  \
# isonum
# iso0000                                   0
# iso0001                                   0
# iso0002                                   0
# iso0003                                  64
# iso0004                                   0
#
#          BB_RT_1_340_335_Hek1053_read_count  \
# isonum
# iso0000                                   0
# iso0001                                   0
# iso0002                                   0
# iso0003                                  59
# iso0004                                   1
#
#          BB_RT_1b_340_243_Hek1053_read_count  ...  \
# isonum                                        ...
# iso0000                                    0  ...
# iso0001                                    0  ...
# iso0002                                    0  ...
# iso0003                                  140  ...
# iso0004                                    1  ...
#
#          BB_RT_2_ODT_335_Cos1054_read_count  \
# isonum
# iso0000                                   0
# iso0001                                   0
# iso0002                                   0
# iso0003                                   0
# iso0004                                   0
#
#          BB_RT_2_ODT_335_Hek1054_read_count  \
# isonum
# iso0000                                   0
# iso0001                                   0
# iso0002                                   0
# iso0003                                   0
# iso0004                                   0
#
#          BB_RT_3_340_243_Cos1055_read_count  \
# isonum
# iso0000                                   0
# iso0001                                   0
# iso0002                                   0
# iso0003                                   0
# iso0004                                   0
#
#          BB_RT_3_340_243_Hek1055_read_count  \
# isonum
# iso0000                                   0
# iso0001                                   0
# iso0002                                   0
# iso0003                                   0
# iso0004                                   0
#
#          BB_RT_3_340_335_Cos1055_read_count  \
# isonum
# iso0000                                   0
# iso0001                                   0
# iso0002                                   0
# iso0003                                   0
# iso0004                                   0
#
#          BB_RT_3_340_335_Hek1055_read_count  \
# isonum
# iso0000                                   0
# iso0001                                   0
# iso0002                                   0
# iso0003                                   0
# iso0004                                   0
#
#          BB_RT_3_ODT_243_Cos1055_read_count  \
# isonum
# iso0000                                   0
# iso0001                                   0
# iso0002                                   0
# iso0003                                   0
# iso0004                                   0
#
#          BB_RT_3_ODT_243_Hek1055_read_count  \
# isonum
# iso0000                                   0
# iso0001                                   0
# iso0002                                   0
# iso0003                                   0
# iso0004                                   0
#
#          BB_RT_3_ODT_335_cos1055_read_count  \
# isonum
# iso0000                                   0
# iso0001                                   0
# iso0002                                   0
# iso0003                                   0
# iso0004                                   0
#
#          BB_RT_3_ODT_335_Hek1055_read_count
# isonum
# iso0000                                   0
# iso0001                                   0
# iso0002                                   0
# iso0003                                   0
# iso0004                                   0
#
# [5 rows x 33 columns]

# %%
isogrp_df.loc[ isogrp_df.isoform == ((1267, 1359),) ]
# Out:
#                  isoform  BB_test_Cos1053_JKLab0340_MM1B_read_count  \
# isonum
# iso2659  ((1267, 1359),)                                    2400975
#
#          BB_test_Cos1053_JKLab0340_MM2B_read_count  \
# isonum
# iso2659                                    5054350
#
#          BB_test_Cos1053_oligodT_MM1B_read_count  \
# isonum
# iso2659                                  2190614
#
#          BB_test_Cos1053_oligodT_MM2B_read_count  \
# isonum
# iso2659                                  6181724
#
#          BB_RT_1_340_243_Cos1053_read_count  \
# isonum
# iso2659                             1852418
#
#          BB_RT_1_340_243_Hek1053_read_count  \
# isonum
# iso2659                             3409650
#
#          BB_RT_1_340_335_Cos1053_read_count  \
# isonum
# iso2659                              499731
#
#          BB_RT_1_340_335_Hek1053_read_count  \
# isonum
# iso2659                             1003786
#
#          BB_RT_1b_340_243_Hek1053_read_count  ...  \
# isonum                                        ...
# iso2659                              3096744  ...
#
#          BB_RT_2_ODT_335_Cos1054_read_count  \
# isonum
# iso2659                              148022
#
#          BB_RT_2_ODT_335_Hek1054_read_count  \
# isonum
# iso2659                              670847
#
#          BB_RT_3_340_243_Cos1055_read_count  \
# isonum
# iso2659                              935423
#
#          BB_RT_3_340_243_Hek1055_read_count  \
# isonum
# iso2659                             2235303
#
#          BB_RT_3_340_335_Cos1055_read_count  \
# isonum
# iso2659                              642084
#
#          BB_RT_3_340_335_Hek1055_read_count  \
# isonum
# iso2659                             1424797
#
#          BB_RT_3_ODT_243_Cos1055_read_count  \
# isonum
# iso2659                             2636654
#
#          BB_RT_3_ODT_243_Hek1055_read_count  \
# isonum
# iso2659                             1605049
#
#          BB_RT_3_ODT_335_cos1055_read_count  \
# isonum
# iso2659                              768588
#
#          BB_RT_3_ODT_335_Hek1055_read_count
# isonum
# iso2659                             1088778
#
# [1 rows x 33 columns]

# %%
isogrp_df.loc[ isogrp_df.isoform == ((1267, 1350),) ]
# Out:
#                  isoform  BB_test_Cos1053_JKLab0340_MM1B_read_count  \
# isonum
# iso1373  ((1267, 1350),)                                    2202889
#
#          BB_test_Cos1053_JKLab0340_MM2B_read_count  \
# isonum
# iso1373                                    4607597
#
#          BB_test_Cos1053_oligodT_MM1B_read_count  \
# isonum
# iso1373                                  1962858
#
#          BB_test_Cos1053_oligodT_MM2B_read_count  \
# isonum
# iso1373                                  5733661
#
#          BB_RT_1_340_243_Cos1053_read_count  \
# isonum
# iso1373                             1642915
#
#          BB_RT_1_340_243_Hek1053_read_count  \
# isonum
# iso1373                             3029467
#
#          BB_RT_1_340_335_Cos1053_read_count  \
# isonum
# iso1373                              457547
#
#          BB_RT_1_340_335_Hek1053_read_count  \
# isonum
# iso1373                              943894
#
#          BB_RT_1b_340_243_Hek1053_read_count  ...  \
# isonum                                        ...
# iso1373                              2728074  ...
#
#          BB_RT_2_ODT_335_Cos1054_read_count  \
# isonum
# iso1373                              132018
#
#          BB_RT_2_ODT_335_Hek1054_read_count  \
# isonum
# iso1373                              644707
#
#          BB_RT_3_340_243_Cos1055_read_count  \
# isonum
# iso1373                              854764
#
#          BB_RT_3_340_243_Hek1055_read_count  \
# isonum
# iso1373                             1928910
#
#          BB_RT_3_340_335_Cos1055_read_count  \
# isonum
# iso1373                              607919
#
#          BB_RT_3_340_335_Hek1055_read_count  \
# isonum
# iso1373                             1469642
#
#          BB_RT_3_ODT_243_Cos1055_read_count  \
# isonum
# iso1373                             2365654
#
#          BB_RT_3_ODT_243_Hek1055_read_count  \
# isonum
# iso1373                             1373452
#
#          BB_RT_3_ODT_335_cos1055_read_count  \
# isonum
# iso1373                              730185
#
#          BB_RT_3_ODT_335_Hek1055_read_count
# isonum
# iso1373                             1190025
#
# [1 rows x 33 columns]

# %%
satbls = ! ls /nfs/turbo/umms-kitzmanj/oldvol2/jacob/proj/jensplice/20220426_wt1_subasm_filter_stringent/sapipe/sa/*.haps.all.txt

# %%
satbl_fn = { sa.split( '/')[ -1 ].split( '.' )[ 0 ]: pd.read_table( sa ).set_index( 'readgroupid' ) for sa in satbls }

# %%
for lib in satbl_fn.keys():
    
    satbl_fn[ lib ] = satbl_fn[ lib ][ [ col for col in satbl_fn[ lib ] if not col.startswith( 'nbp_' ) ] ].copy()

# %%
exonbed = pbt.BedTool( '/nfs/kitzman2/smithcat/proj/wt1_2022/refs/wt1_ex9.bed' )

# %%
isos = jn.make_junction_graph( exonbed )

# %%
isos
# Out:
# {'iso00': ((650, 696), (1267, 1350), (3479, 3533)),
#  'iso01': ((650, 696), (1267, 1359), (3479, 3533)),
#  'iso02': ((650, 696), (3479, 3533))}

# %%
unique_jns = list( { jn for grp,jn_tups in isos.items() for jn_tup in jn_tups for jn in jn_tup
                       if 696 < jn < 3479 } )

# %%
unique_jns
# Out:
# [1267, 1350, 1359]

# %%
msamp_rnabam = { samp : pysam.AlignmentFile( msamp_fn[ samp ], 'rb' ) for samp in msamp_fn }

# %%
for lib in satbl_fn:
    
    print( lib )
    
    print( satbl_fn[ lib ].head() )
# Out:
# JKP1053
#                          passes                              status  \
# readgroupid
# AAAAAAAATCACGACCCTCCTGG   False  possible_chimeric_no_major_variant
# AAAAAAAGGGCTTCCGGGTATGG    True                   no_variants_input
# AAAAAAAGGGTTCCAGACTGTGG   False                     toomanymajorvar
# AAAAAAAGTAGTCTGGTGTGTGG    True                                pass
# AAAAAAATACCCCGGATGATTGG   False  possible_chimeric_no_major_variant
#
#                          n_variants_passing  \
# readgroupid
# AAAAAAAATCACGACCCTCCTGG                   6
# AAAAAAAGGGCTTCCGGGTATGG                   0
# AAAAAAAGGGTTCCAGACTGTGG                   2
# AAAAAAAGTAGTCTGGTGTGTGG                   1
# AAAAAAATACCCCGGATGATTGG                   1
#
#                                                               variant_list
# readgroupid
# AAAAAAAATCACGACCCTCCTGG  jkp815:1225:CACAT:CC,jkp815:1231:GTTAG:GTAG,jk...
# AAAAAAAGGGCTTCCGGGTATGG                                                NaN
# AAAAAAAGGGTTCCAGACTGTGG  jkp815:1252:T:G,jkp815:1279:TCCAGTGTAAAACTTGTC...
# AAAAAAAGTAGTCTGGTGTGTGG                                    jkp815:1387:T:C
# AAAAAAATACCCCGGATGATTGG                                    jkp815:1392:T:A
# JKP1054
#                          passes                              status  \
# readgroupid
# AAAAAAAGGGGGCAATCTTGTGG    True                   no_variants_input
# AAAAAAAGTGCCCTGAGCGTTGG   False  possible_chimeric_no_major_variant
# AAAAAAATCAATGGCATTCATGG    True       apparently_wt_no_passing_vars
# AAAAAAATTAGGTATGGGGGTGG   False  possible_chimeric_no_major_variant
# AAAAAAATTTAATGGAGATGTGG    True                   no_variants_input
#
#                          n_variants_passing     variant_list
# readgroupid
# AAAAAAAGGGGGCAATCTTGTGG                   0              NaN
# AAAAAAAGTGCCCTGAGCGTTGG                   1  jkp815:1227:C:G
# AAAAAAATCAATGGCATTCATGG                   0              NaN
# AAAAAAATTAGGTATGGGGGTGG                   1  jkp815:1249:C:G
# AAAAAAATTTAATGGAGATGTGG                   0              NaN
# JKP1055
#                          passes                              status  \
# readgroupid
# AAAAAAAAATCTTTTGAGGTTGG   False  possible_chimeric_no_major_variant
# AAAAAAAACCCCATGCATATTGG   False  possible_chimeric_no_major_variant
# AAAAAAAAGATTGTTATGTGTGG   False  possible_chimeric_no_major_variant
# AAAAAAAATAATTTTTCATCTGG    True                   no_variants_input
# AAAAAAAATAGAGAGCGGATTGG   False  possible_chimeric_no_major_variant
#
#                          n_variants_passing  \
# readgroupid
# AAAAAAAAATCTTTTGAGGTTGG                   1
# AAAAAAAACCCCATGCATATTGG                   4
# AAAAAAAAGATTGTTATGTGTGG                   2
# AAAAAAAATAATTTTTCATCTGG                   0
# AAAAAAAATAGAGAGCGGATTGG                   1
#
#                                                               variant_list
# readgroupid
# AAAAAAAAATCTTTTGAGGTTGG                                    jkp815:1298:G:A
# AAAAAAAACCCCATGCATATTGG  jkp815:1343:T:A,jkp815:1364:GTA:GA,jkp815:1368...
# AAAAAAAAGATTGTTATGTGTGG                    jkp815:1307:C:A,jkp815:1361:T:C
# AAAAAAAATAATTTTTCATCTGG                                                NaN
# AAAAAAAATAGAGAGCGGATTGG                                    jkp815:1399:T:G

# %%
??jn.get_all_isoforms_pe

# %%
??jn.summarize_isos_by_var_bc_pe

# %%
# %%time
#1 min/sample

iso_df_stats = { lib: jn.summarize_isos_by_var_bc_pe( { samp: bam for samp,bam in msamp_rnabam.items()
                                                        if lib.replace( 'JKP', '' ) in samp },
                                                      [ ( 649, 696 ), ( 3478, 3533 ) ],
                                                      satbl_fn[ lib ],
                                                      isogrp_df,
                                                      unique_jns,
                                                      [ ( ( 1266, 1350 ), ), ( ( 1266, 1359 ), ), () ],
                                                      spl_tol = 3,
                                                      indel_tol = 20,
                                                      min_matches_for = 70,
                                                      min_matches_rev = 50,
                                                      bc_tag = 'BC',
                                                     ) 
                  for lib in satbl_fn }
# Out:
# BB_test_Cos1053_JKLab0340_MM1B
# Barcodes processed: 1000
# Reads processed: 12043
# Barcodes processed: 2000
# Reads processed: 26823
# Barcodes processed: 3000
# Reads processed: 45264
# Barcodes processed: 4000
# Reads processed: 55952
# Barcodes processed: 5000
# Reads processed: 70486
# Barcodes processed: 6000
# Reads processed: 81201
# Barcodes processed: 7000
# Reads processed: 93441
# Barcodes processed: 8000
# Reads processed: 106029
# Barcodes processed: 9000
# Reads processed: 116719
# Barcodes processed: 10000
# Reads processed: 130977
# Barcodes processed: 11000
# Reads processed: 141227
# Barcodes processed: 12000
# Reads processed: 153097
# Barcodes processed: 13000
# Reads processed: 169579
# Barcodes processed: 14000
# Reads processed: 183217
# Barcodes processed: 15000
# Reads processed: 199904
# Barcodes processed: 16000
# Reads processed: 215448
# Barcodes processed: 17000
# Reads processed: 228428
# Barcodes processed: 18000
# Reads processed: 241930
# Barcodes processed: 19000
# Reads processed: 250952
# Barcodes processed: 20000
# Reads processed: 264514
# Barcodes processed: 21000
# Reads processed: 274974
# Barcodes processed: 22000
# Reads processed: 287725
# Barcodes processed: 23000
# Reads processed: 300115
# Barcodes processed: 24000
# Reads processed: 311744
# Barcodes processed: 25000
# Reads processed: 324550
# Barcodes processed: 26000
# Reads processed: 336720
# Barcodes processed: 27000
# Reads processed: 348573
# Barcodes processed: 28000
# Reads processed: 368037
# Barcodes processed: 29000
# Reads processed: 380199
# Barcodes processed: 30000
# Reads processed: 393069
# Barcodes processed: 31000
# Reads processed: 405628
# Barcodes processed: 32000
# Reads processed: 418724
# Barcodes processed: 33000
# Reads processed: 430777
# Barcodes processed: 34000
# Reads processed: 440094
# Barcodes processed: 35000
# Reads processed: 451000
# Barcodes processed: 36000
# Reads processed: 464623
# Barcodes processed: 37000
# Reads processed: 476537
# Barcodes processed: 38000
# Reads processed: 492243
# Barcodes processed: 39000
# Reads processed: 505953
# Barcodes processed: 40000
# Reads processed: 519899
# Barcodes processed: 41000
# Reads processed: 533531
# Barcodes processed: 42000
# Reads processed: 545202
# Barcodes processed: 43000
# Reads processed: 559682
# Barcodes processed: 44000
# Reads processed: 569939
# Barcodes processed: 45000
# Reads processed: 584138
# Barcodes processed: 46000
# Reads processed: 597486
# Barcodes processed: 47000
# Reads processed: 611823
# Barcodes processed: 48000
# Reads processed: 625028
# Barcodes processed: 49000
# Reads processed: 636421
# Barcodes processed: 50000
# Reads processed: 651167
# Barcodes processed: 51000
# Reads processed: 661914
# Barcodes processed: 52000
# Reads processed: 672594
# Barcodes processed: 53000
# Reads processed: 686434
# Barcodes processed: 54000
# Reads processed: 700990
# Barcodes processed: 55000
# Reads processed: 714642
# Barcodes processed: 56000
# Reads processed: 726618
# Barcodes processed: 57000
# Reads processed: 740265
# Barcodes processed: 58000
# Reads processed: 752648
# Barcodes processed: 59000
# Reads processed: 763837
# Barcodes processed: 60000
# Reads processed: 774960
# Barcodes processed: 61000
# Reads processed: 786445
# Barcodes processed: 62000
# Reads processed: 800261
# Barcodes processed: 63000
# Reads processed: 812657
# Barcodes processed: 64000
# Reads processed: 824377
# Barcodes processed: 65000
# Reads processed: 837416
# Barcodes processed: 66000
# Reads processed: 853759
# Barcodes processed: 67000
# Reads processed: 866961
# Barcodes processed: 68000
# Reads processed: 879781
# Barcodes processed: 69000
# Reads processed: 898619
# Barcodes processed: 70000
# Reads processed: 911464
# Barcodes processed: 71000
# Reads processed: 924193
# Barcodes processed: 72000
# Reads processed: 934983
# Barcodes processed: 73000
# Reads processed: 945734
# Barcodes processed: 74000
# Reads processed: 959585
# Barcodes processed: 75000
# Reads processed: 969371
# Barcodes processed: 76000
# Reads processed: 983665
# Barcodes processed: 77000
# Reads processed: 996761
# Barcodes processed: 78000
# Reads processed: 1008134
# Barcodes processed: 79000
# Reads processed: 1020249
# Barcodes processed: 80000
# Reads processed: 1043473
# Barcodes processed: 81000
# Reads processed: 1056561
# Barcodes processed: 82000
# Reads processed: 1071160
# Barcodes processed: 83000
# Reads processed: 1086367
# Barcodes processed: 84000
# Reads processed: 1100354
# Barcodes processed: 85000
# Reads processed: 1114582
# Barcodes processed: 86000
# Reads processed: 1128944
# Barcodes processed: 87000
# Reads processed: 1144035
# Barcodes processed: 88000
# Reads processed: 1158017
# Barcodes processed: 89000
# Reads processed: 1171076
# Barcodes processed: 90000
# Reads processed: 1184654
# Barcodes processed: 91000
# Reads processed: 1196048
# Barcodes processed: 92000
# Reads processed: 1213314
# Barcodes processed: 93000
# Reads processed: 1226194
# Barcodes processed: 94000
# Reads processed: 1238120
# Barcodes processed: 95000
# Reads processed: 1253772
# Barcodes processed: 96000
# Reads processed: 1271862
# Barcodes processed: 97000
# Reads processed: 1285665
# Barcodes processed: 98000
# Reads processed: 1299195
# Barcodes processed: 99000
# Reads processed: 1311139
# Barcodes processed: 100000
# Reads processed: 1322601
# Barcodes processed: 101000
# Reads processed: 1333234
# Barcodes processed: 102000
# Reads processed: 1346293
# Barcodes processed: 103000
# Reads processed: 1358481
# Barcodes processed: 104000
# Reads processed: 1371111
# Barcodes processed: 105000
# Reads processed: 1382725
# Barcodes processed: 106000
# Reads processed: 1393170
# Barcodes processed: 107000
# Reads processed: 1405429
# Barcodes processed: 108000
# Reads processed: 1416863
# Barcodes processed: 109000
# Reads processed: 1431048
# Barcodes processed: 110000
# Reads processed: 1457732
# Barcodes processed: 111000
# Reads processed: 1469239
# Barcodes processed: 112000
# Reads processed: 1481194
# Barcodes processed: 113000
# Reads processed: 1504015
# Barcodes processed: 114000
# Reads processed: 1517689
# Barcodes processed: 115000
# Reads processed: 1530830
# Barcodes processed: 116000
# Reads processed: 1542299
# Barcodes processed: 117000
# Reads processed: 1559801
# Barcodes processed: 118000
# Reads processed: 1569686
# Barcodes processed: 119000
# Reads processed: 1581763
# Barcodes processed: 120000
# Reads processed: 1594504
# Barcodes processed: 121000
# Reads processed: 1607081
# Barcodes processed: 122000
# Reads processed: 1619610
# Barcodes processed: 123000
# Reads processed: 1632434
# Barcodes processed: 124000
# Reads processed: 1641036
# Barcodes processed: 125000
# Reads processed: 1651782
# Barcodes processed: 126000
# Reads processed: 1664120
# Barcodes processed: 127000
# Reads processed: 1680726
# Barcodes processed: 128000
# Reads processed: 1691357
# Barcodes processed: 129000
# Reads processed: 1703545
# Barcodes processed: 130000
# Reads processed: 1713610
# Barcodes processed: 131000
# Reads processed: 1728028
# Barcodes processed: 132000
# Reads processed: 1741448
# Barcodes processed: 133000
# Reads processed: 1755182
# Barcodes processed: 134000
# Reads processed: 1767433
# Barcodes processed: 135000
# Reads processed: 1778102
# Barcodes processed: 136000
# Reads processed: 1790129
# Barcodes processed: 137000
# Reads processed: 1799649
# Barcodes processed: 138000
# Reads processed: 1809107
# Barcodes processed: 139000
# Reads processed: 1820831
# Barcodes processed: 140000
# Reads processed: 1834386
# Barcodes processed: 141000
# Reads processed: 1844566
# Barcodes processed: 142000
# Reads processed: 1855493
# Barcodes processed: 143000
# Reads processed: 1868423
# Barcodes processed: 144000
# Reads processed: 1878561
# Barcodes processed: 145000
# Reads processed: 1890956
# Barcodes processed: 146000
# Reads processed: 1903900
# Barcodes processed: 147000
# Reads processed: 1917224
# Barcodes processed: 148000
# Reads processed: 1929616
# Barcodes processed: 149000
# Reads processed: 1940629
# Barcodes processed: 150000
# Reads processed: 1952067
# Barcodes processed: 151000
# Reads processed: 1962768
# Barcodes processed: 152000
# Reads processed: 1979764
# Barcodes processed: 153000
# Reads processed: 1993203
# Barcodes processed: 154000
# Reads processed: 2006560
# Barcodes processed: 155000
# Reads processed: 2021510
# Barcodes processed: 156000
# Reads processed: 2033702
# Barcodes processed: 157000
# Reads processed: 2045506
# Barcodes processed: 158000
# Reads processed: 2057262
# Barcodes processed: 159000
# Reads processed: 2067225
# Barcodes processed: 160000
# Reads processed: 2079533
# Barcodes processed: 161000
# Reads processed: 2088185
# Barcodes processed: 162000
# Reads processed: 2100645
# Barcodes processed: 163000
# Reads processed: 2110863
# Barcodes processed: 164000
# Reads processed: 2124115
# Barcodes processed: 165000
# Reads processed: 2136276
# Barcodes processed: 166000
# Reads processed: 2148176
# Barcodes processed: 167000
# Reads processed: 2160578
# Barcodes processed: 168000
# Reads processed: 2173357
# Barcodes processed: 169000
# Reads processed: 2182782
# Barcodes processed: 170000
# Reads processed: 2194240
# Barcodes processed: 171000
# Reads processed: 2206078
# Barcodes processed: 172000
# Reads processed: 2221336
# Barcodes processed: 173000
# Reads processed: 2232600
# Barcodes processed: 174000
# Reads processed: 2245228
# Barcodes processed: 175000
# Reads processed: 2258153
# Barcodes processed: 176000
# Reads processed: 2270444
# Barcodes processed: 177000
# Reads processed: 2280681
# Barcodes processed: 178000
# Reads processed: 2291596
# Barcodes processed: 179000
# Reads processed: 2303953
# Barcodes processed: 180000
# Reads processed: 2318261
# Barcodes processed: 181000
# Reads processed: 2328525
# Barcodes processed: 182000
# Reads processed: 2337051
# Barcodes processed: 183000
# Reads processed: 2349839
# Barcodes processed: 184000
# Reads processed: 2362321
# Barcodes processed: 185000
# Reads processed: 2371893
# Barcodes processed: 186000
# Reads processed: 2385385
# Barcodes processed: 187000
# Reads processed: 2393399
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# ~/miniconda3/envs/splai3/lib/python3.7/site-packages/pandas/core/internals/construction.py in _list_to_arrays(data, columns, coerce_float, dtype)
#     567     try:
# --> 568         columns = _validate_or_indexify_columns(content, columns)
#     569         result = _convert_object_array(content, dtype=dtype, coerce_float=coerce_float)
#
# ~/miniconda3/envs/splai3/lib/python3.7/site-packages/pandas/core/internals/construction.py in _validate_or_indexify_columns(content, columns)
#     692             raise AssertionError(
# --> 693                 f"{len(columns)} columns passed, passed data had "
#     694                 f"{len(content)} columns"
#
# AssertionError: 38 columns passed, passed data had 1 columns
#
# The above exception was the direct cause of the following exception:
#
# ValueError                                Traceback (most recent call last)
# <timed exec> in <module>
#
# <timed exec> in <dictcomp>(.0)
#
# ~/splfxseq/splanl/junction_scorer.py in summarize_isos_by_var_bc_pe(align_by_samp_dict, cnst_exons, satbl, iso_df, unique_jns, canonical_isos, spl_tol, min_matches_for, min_matches_rev, indel_tol, exising_iso_stats_df, print_count, min_maxbc_count, tol, min_cluster_size, clustered_bc_ave, min_bc_max_reads, bc_tag)
#     828         bc_cnts = pd.DataFrame.from_dict( tot_bc_count,
#     829                                            orient = 'index',
# --> 830                                            columns = samp + '_num_bcs' )
#     831
#     832         out_tbl = pd.merge( out_tbl, bc_cnts, left_index=True, right_index=True, how="outer")
#
# ~/miniconda3/envs/splai3/lib/python3.7/site-packages/pandas/core/frame.py in from_dict(cls, data, orient, dtype, columns)
#    1371             raise ValueError("only recognize index or columns for orient")
#    1372
# -> 1373         return cls(data, index=index, columns=columns, dtype=dtype)
#    1374
#    1375     def to_numpy(
#
# ~/miniconda3/envs/splai3/lib/python3.7/site-packages/pandas/core/frame.py in __init__(self, data, index, columns, dtype, copy)
#     568                     if is_named_tuple(data[0]) and columns is None:
#     569                         columns = data[0]._fields
# --> 570                     arrays, columns = to_arrays(data, columns, dtype=dtype)
#     571                     columns = ensure_index(columns)
#     572
#
# ~/miniconda3/envs/splai3/lib/python3.7/site-packages/pandas/core/internals/construction.py in to_arrays(data, columns, coerce_float, dtype)
#     526         return [], []  # columns if columns is not None else []
#     527     if isinstance(data[0], (list, tuple)):
# --> 528         return _list_to_arrays(data, columns, coerce_float=coerce_float, dtype=dtype)
#     529     elif isinstance(data[0], abc.Mapping):
#     530         return _list_of_dict_to_arrays(
#
# ~/miniconda3/envs/splai3/lib/python3.7/site-packages/pandas/core/internals/construction.py in _list_to_arrays(data, columns, coerce_float, dtype)
#     569         result = _convert_object_array(content, dtype=dtype, coerce_float=coerce_float)
#     570     except AssertionError as e:
# --> 571         raise ValueError(e) from e
#     572     return result, columns
#     573
#
# ValueError: 38 columns passed, passed data had 1 columns

# %%
for lib in iso_df_stats:
    print( lib, iso_df_stats[ lib ].shape )
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-32-c2b5cc8ecb65> in <module>
# ----> 1 for lib in iso_df_stats:
#       2     print( lib, iso_df_stats[ lib ].shape )
#
# NameError: name 'iso_df_stats' is not defined

# %%
for lib in iso_df_stats:
    print( lib, iso_df_stats[ lib ].query( 'total_passfilt > 0' ).shape )

# %%
for lib in iso_df_stats:
    print( lib, ( iso_df_stats[ lib ].query( 'total_passfilt == 0' ).total_read_count.sum() / iso_df_stats[ lib ].total_read_count.sum() )*100 )
# Out:
# JKP1053 1.2168247578206421
# JKP1054 1.3293475774601244
# JKP1055 1.3169089402526364

# %%
for lib in iso_df_stats:
    print( lib, ( iso_df_stats[ lib ].query( 'total_passfilt == 0' ).total_num_bcs.sum() / iso_df_stats[ lib ].total_num_bcs.sum() )*100 )
# Out:
# JKP1053 3.1005815309218083
# JKP1054 2.817455582829159
# JKP1055 1.7670238501389146

# %%
iso_df_stats[ 'JKP1053' ]
# Out:
#                                             isoform  \
# isonum
# iso0000                ((1136, 1225), (1301, 1350))
# iso0001                ((1267, 1339), (2660, 2664))
# iso0002                ((1267, 1290), (1320, 1350))
# iso0003                ((1267, 1314), (1337, 1359))
# iso0004                ((1267, 1282), (1328, 1359))
# ...                                             ...
# iso7347                ((1161, 1228), (1308, 1350))
# iso7348                ((1236, 1242), (1266, 1350))
# iso7349                ((1146, 1222), (1281, 1359))
# iso7350                             ((1284, 1348),)
# iso7351  ((1267, 1306), (1563, 1568), (2040, 2045))
#
#          BB_test_Cos1053_JKLab0340_MM1B_read_count  \
# isonum
# iso0000                                          0
# iso0001                                          0
# iso0002                                          0
# iso0003                                          1
# iso0004                                          0
# ...                                            ...
# iso7347                                          0
# iso7348                                          0
# iso7349                                          0
# iso7350                                          0
# iso7351                                          0
#
#          BB_test_Cos1053_JKLab0340_MM2B_read_count  \
# isonum
# iso0000                                          0
# iso0001                                          0
# iso0002                                          0
# iso0003                                        273
# iso0004                                          0
# ...                                            ...
# iso7347                                          0
# iso7348                                          0
# iso7349                                          0
# iso7350                                          1
# iso7351                                          0
#
#          BB_test_Cos1053_oligodT_MM1B_read_count  \
# isonum
# iso0000                                        0
# iso0001                                        0
# iso0002                                        0
# iso0003                                        0
# iso0004                                        2
# ...                                          ...
# iso7347                                        0
# iso7348                                        0
# iso7349                                        0
# iso7350                                        0
# iso7351                                        0
#
#          BB_test_Cos1053_oligodT_MM2B_read_count  \
# isonum
# iso0000                                        0
# iso0001                                        0
# iso0002                                        0
# iso0003                                        0
# iso0004                                        0
# ...                                          ...
# iso7347                                        0
# iso7348                                        0
# iso7349                                        0
# iso7350                                        0
# iso7351                                        0
#
#          BB_RT_1_340_243_Cos1053_read_count  \
# isonum
# iso0000                                   0
# iso0001                                   0
# iso0002                                   0
# iso0003                                   1
# iso0004                                   0
# ...                                     ...
# iso7347                                   0
# iso7348                                   0
# iso7349                                   0
# iso7350                                   0
# iso7351                                   0
#
#          BB_RT_1_340_243_Hek1053_read_count  \
# isonum
# iso0000                                   0
# iso0001                                   0
# iso0002                                   0
# iso0003                                 127
# iso0004                                   0
# ...                                     ...
# iso7347                                   0
# iso7348                                   0
# iso7349                                   3
# iso7350                                   0
# iso7351                                   0
#
#          BB_RT_1_340_335_Cos1053_read_count  \
# isonum
# iso0000                                   0
# iso0001                                   0
# iso0002                                   0
# iso0003                                  64
# iso0004                                   0
# ...                                     ...
# iso7347                                   0
# iso7348                                   0
# iso7349                                   0
# iso7350                                   0
# iso7351                                   0
#
#          BB_RT_1_340_335_Hek1053_read_count  \
# isonum
# iso0000                                   0
# iso0001                                   0
# iso0002                                   0
# iso0003                                  59
# iso0004                                   1
# ...                                     ...
# iso7347                                   0
# iso7348                                   0
# iso7349                                   0
# iso7350                                   0
# iso7351                                   0
#
#          BB_RT_1b_340_243_Hek1053_read_count  ...  \
# isonum                                        ...
# iso0000                                    0  ...
# iso0001                                    0  ...
# iso0002                                    0  ...
# iso0003                                  140  ...
# iso0004                                    1  ...
# ...                                      ...  ...
# iso7347                                    0  ...
# iso7348                                    1  ...
# iso7349                                    3  ...
# iso7350                                    0  ...
# iso7351                                    0  ...
#
#          BB_RT_1_ODT_335_Cos1053_filter  BB_RT_1_ODT_335_Hek1053_num_bcs  \
# isonum
# iso0000                             0.0                              0.0
# iso0001                             0.0                              0.0
# iso0002                             0.0                              0.0
# iso0003                             0.0                             10.0
# iso0004                             0.0                              0.0
# ...                                 ...                              ...
# iso7347                             0.0                              0.0
# iso7348                             0.0                              0.0
# iso7349                             0.0                              0.0
# iso7350                             0.0                              0.0
# iso7351                             0.0                              0.0
#
#          BB_RT_1_ODT_335_Hek1053_num_vars  \
# isonum
# iso0000                               0.0
# iso0001                               0.0
# iso0002                               0.0
# iso0003                               6.0
# iso0004                               0.0
# ...                                   ...
# iso7347                               0.0
# iso7348                               0.0
# iso7349                               0.0
# iso7350                               0.0
# iso7351                               0.0
#
#          BB_RT_1_ODT_335_Hek1053_max_reads_per_bc  \
# isonum
# iso0000                                       0.0
# iso0001                                       0.0
# iso0002                                       0.0
# iso0003                                       7.0
# iso0004                                       0.0
# ...                                           ...
# iso7347                                       0.0
# iso7348                                       0.0
# iso7349                                       0.0
# iso7350                                       0.0
# iso7351                                       0.0
#
#          BB_RT_1_ODT_335_Hek1053_max_bc_per_var  \
# isonum
# iso0000                                     0.0
# iso0001                                     0.0
# iso0002                                     0.0
# iso0003                                     5.0
# iso0004                                     0.0
# ...                                         ...
# iso7347                                     0.0
# iso7348                                     0.0
# iso7349                                     0.0
# iso7350                                     0.0
# iso7351                                     0.0
#
#          BB_RT_1_ODT_335_Hek1053_filter  total_read_count  total_num_bcs  \
# isonum
# iso0000                             0.0                 3            1.0
# iso0001                             0.0                 1            0.0
# iso0002                             0.0                 2            1.0
# iso0003                             3.0              1106          170.0
# iso0004                             0.0                12            2.0
# ...                                 ...               ...            ...
# iso7347                             0.0                 2            0.0
# iso7348                             0.0                 1            1.0
# iso7349                             0.0                12            1.0
# iso7350                             0.0                 3            1.0
# iso7351                             0.0                 6            0.0
#
#          total_num_vars  total_passfilt
# isonum
# iso0000             1.0               0
# iso0001             0.0               0
# iso0002             1.0               0
# iso0003           129.0               9
# iso0004             2.0               0
# ...                 ...             ...
# iso7347             0.0               0
# iso7348             1.0               0
# iso7349             1.0               0
# iso7350             1.0               0
# iso7351             0.0               0
#
# [7352 rows x 117 columns]

# %%
bdout = '/nfs/kitzman2/smithcat/proj/wt1_2022/ex9_data/'

# %%
for lib in iso_df_stats.keys():    
    iso_df_stats[ lib ].reset_index().to_csv( bdout + 'wt1_ex9_%s_isoforms_2022-0519.txt' % lib,
                                               sep = '\t',
                                               index = False )

# %%
iso_df_stats_all = iso_df_stats[ 'JKP1053' ].merge( iso_df_stats[ 'JKP1054' ],
                                                    left_index = True,
                                                    right_index = True,
                                                    how = 'outer',
                                                    suffixes = ( '_JKP1053', '_JKP1054' )
                                                  )

# %%
iso_df_stats_all
# Out:
#                                     isoform_JKP1053  \
# isonum
# iso0000                ((1136, 1225), (1301, 1350))
# iso0001                ((1267, 1339), (2660, 2664))
# iso0002                ((1267, 1290), (1320, 1350))
# iso0003                ((1267, 1314), (1337, 1359))
# iso0004                ((1267, 1282), (1328, 1359))
# ...                                             ...
# iso7347                ((1161, 1228), (1308, 1350))
# iso7348                ((1236, 1242), (1266, 1350))
# iso7349                ((1146, 1222), (1281, 1359))
# iso7350                             ((1284, 1348),)
# iso7351  ((1267, 1306), (1563, 1568), (2040, 2045))
#
#          BB_test_Cos1053_JKLab0340_MM1B_read_count_JKP1053  \
# isonum
# iso0000                                                  0
# iso0001                                                  0
# iso0002                                                  0
# iso0003                                                  1
# iso0004                                                  0
# ...                                                    ...
# iso7347                                                  0
# iso7348                                                  0
# iso7349                                                  0
# iso7350                                                  0
# iso7351                                                  0
#
#          BB_test_Cos1053_JKLab0340_MM2B_read_count_JKP1053  \
# isonum
# iso0000                                                  0
# iso0001                                                  0
# iso0002                                                  0
# iso0003                                                273
# iso0004                                                  0
# ...                                                    ...
# iso7347                                                  0
# iso7348                                                  0
# iso7349                                                  0
# iso7350                                                  1
# iso7351                                                  0
#
#          BB_test_Cos1053_oligodT_MM1B_read_count_JKP1053  \
# isonum
# iso0000                                                0
# iso0001                                                0
# iso0002                                                0
# iso0003                                                0
# iso0004                                                2
# ...                                                  ...
# iso7347                                                0
# iso7348                                                0
# iso7349                                                0
# iso7350                                                0
# iso7351                                                0
#
#          BB_test_Cos1053_oligodT_MM2B_read_count_JKP1053  \
# isonum
# iso0000                                                0
# iso0001                                                0
# iso0002                                                0
# iso0003                                                0
# iso0004                                                0
# ...                                                  ...
# iso7347                                                0
# iso7348                                                0
# iso7349                                                0
# iso7350                                                0
# iso7351                                                0
#
#          BB_RT_1_340_243_Cos1053_read_count_JKP1053  \
# isonum
# iso0000                                           0
# iso0001                                           0
# iso0002                                           0
# iso0003                                           1
# iso0004                                           0
# ...                                             ...
# iso7347                                           0
# iso7348                                           0
# iso7349                                           0
# iso7350                                           0
# iso7351                                           0
#
#          BB_RT_1_340_243_Hek1053_read_count_JKP1053  \
# isonum
# iso0000                                           0
# iso0001                                           0
# iso0002                                           0
# iso0003                                         127
# iso0004                                           0
# ...                                             ...
# iso7347                                           0
# iso7348                                           0
# iso7349                                           3
# iso7350                                           0
# iso7351                                           0
#
#          BB_RT_1_340_335_Cos1053_read_count_JKP1053  \
# isonum
# iso0000                                           0
# iso0001                                           0
# iso0002                                           0
# iso0003                                          64
# iso0004                                           0
# ...                                             ...
# iso7347                                           0
# iso7348                                           0
# iso7349                                           0
# iso7350                                           0
# iso7351                                           0
#
#          BB_RT_1_340_335_Hek1053_read_count_JKP1053  \
# isonum
# iso0000                                           0
# iso0001                                           0
# iso0002                                           0
# iso0003                                          59
# iso0004                                           1
# ...                                             ...
# iso7347                                           0
# iso7348                                           0
# iso7349                                           0
# iso7350                                           0
# iso7351                                           0
#
#          BB_RT_1b_340_243_Hek1053_read_count_JKP1053  ...  \
# isonum                                                ...
# iso0000                                            0  ...
# iso0001                                            0  ...
# iso0002                                            0  ...
# iso0003                                          140  ...
# iso0004                                            1  ...
# ...                                              ...  ...
# iso7347                                            0  ...
# iso7348                                            1  ...
# iso7349                                            3  ...
# iso7350                                            0  ...
# iso7351                                            0  ...
#
#          BB_RT_2_ODT_335_Cos1054_filter  BB_RT_2_ODT_335_Hek1054_num_bcs  \
# isonum
# iso0000                             0.0                              0.0
# iso0001                             0.0                              0.0
# iso0002                             0.0                              0.0
# iso0003                             0.0                              0.0
# iso0004                             0.0                              0.0
# ...                                 ...                              ...
# iso7347                             0.0                              0.0
# iso7348                             0.0                              0.0
# iso7349                             0.0                              0.0
# iso7350                             0.0                              0.0
# iso7351                             0.0                              0.0
#
#          BB_RT_2_ODT_335_Hek1054_num_vars  \
# isonum
# iso0000                               0.0
# iso0001                               0.0
# iso0002                               0.0
# iso0003                               0.0
# iso0004                               0.0
# ...                                   ...
# iso7347                               0.0
# iso7348                               0.0
# iso7349                               0.0
# iso7350                               0.0
# iso7351                               0.0
#
#          BB_RT_2_ODT_335_Hek1054_max_reads_per_bc  \
# isonum
# iso0000                                       0.0
# iso0001                                       0.0
# iso0002                                       0.0
# iso0003                                       0.0
# iso0004                                       0.0
# ...                                           ...
# iso7347                                       0.0
# iso7348                                       0.0
# iso7349                                       0.0
# iso7350                                       0.0
# iso7351                                       0.0
#
#          BB_RT_2_ODT_335_Hek1054_max_bc_per_var  \
# isonum
# iso0000                                     0.0
# iso0001                                     0.0
# iso0002                                     0.0
# iso0003                                     0.0
# iso0004                                     0.0
# ...                                         ...
# iso7347                                     0.0
# iso7348                                     0.0
# iso7349                                     0.0
# iso7350                                     0.0
# iso7351                                     0.0
#
#          BB_RT_2_ODT_335_Hek1054_filter  total_read_count_JKP1054  \
# isonum
# iso0000                             0.0                         3
# iso0001                             0.0                         1
# iso0002                             0.0                         2
# iso0003                             0.0                      1106
# iso0004                             0.0                        12
# ...                                 ...                       ...
# iso7347                             0.0                         2
# iso7348                             0.0                         1
# iso7349                             0.0                        12
# iso7350                             0.0                         3
# iso7351                             0.0                         6
#
#          total_num_bcs_JKP1054  total_num_vars_JKP1054  total_passfilt_JKP1054
# isonum
# iso0000                    0.0                     0.0                       0
# iso0001                    0.0                     0.0                       0
# iso0002                    0.0                     0.0                       0
# iso0003                    0.0                     0.0                       0
# iso0004                    0.0                     0.0                       0
# ...                        ...                     ...                     ...
# iso7347                    0.0                     0.0                       0
# iso7348                    0.0                     0.0                       0
# iso7349                    0.0                     0.0                       0
# iso7350                    0.0                     0.0                       0
# iso7351                    0.0                     0.0                       0
#
# [7352 rows x 194 columns]

# %%
iso_df_stats_all = iso_df_stats_all.merge( iso_df_stats[ 'JKP1055' ].rename( columns = { col: col + '_JKP1055' 
                                                                                         for col in iso_df_stats[ 'JKP1055' ] if col.startswith( 'total_' ) } ),
                                            left_index = True,
                                            right_index = True,
                                            how = 'outer',
                                            suffixes = ( '', '_JKP1055' )
                                        )

# %%
total_cols = [ 'total_read_count', 'total_num_bcs', 'total_num_vars', 'total_passfilt' ]

for col in total_cols:
    
    iso_df_stats_all[ col ] = iso_df_stats_all[ [ lcol for lcol in iso_df_stats_all if col + '_' in lcol ] ].sum( axis = 1 )

# %%
len( bam )
# Out:
# 32

# %%
iso_df_stats_all.shape
# Out:
# (7352, 275)

# %%
iso_df_stats_all.query( 'total_passfilt > 0' ).shape
# Out:
# (473, 275)

# %%
iso_df_stats_all.query( 'total_passfilt >= 16' ).shape
# Out:
# (68, 275)

# %%
( iso_df_stats_all.query( 'total_passfilt == 0' ).total_read_count.sum() / iso_df_stats_all.total_read_count.sum() )*100
# Out:
# 1.1257901513775952

# %%
#is this what I want?
#total reads is # of reads in bam
#would I prefer to have # reads in bcs in subasm?

( iso_df_stats_all.query( 'total_passfilt >= 16' ).total_read_count.sum() / iso_df_stats_all.total_read_count.sum() )*100
# Out:
# 98.60173941032993

# %%
( iso_df_stats_all.query( 'total_passfilt == 0' ).total_num_bcs.sum() / iso_df_stats_all.total_num_bcs.sum() )*100
# Out:
# 2.391724944440723

# %%
( iso_df_stats_all.query( 'total_passfilt >= 16' ).total_num_bcs.sum() / iso_df_stats_all.total_num_bcs.sum() )*100
# Out:
# 97.0093198321134

# %%
iso_df_stats_all.total_num_bcs.isnull().sum()
# Out:
# 0

# %%
iso_df_stats_all.reset_index().to_csv( bdout + 'wt1_ex9_isoforms_2022-0519.txt',
                                               sep = '\t',
                                               index = False )

# %%
import inspect
#from sklearn import tree
#inspect.getsourcelines(tree.tree)

# %%
inspect.getsourcelines( jn.summarize_isos_by_var_bc_pe )
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# <ipython-input-35-185f1c023ddb> in <module>
# ----> 1 inspect.getsourcelines( jn.summarize_isos_by_var_bc_pe )
#
# ~/miniconda3/envs/splai3/lib/python3.7/inspect.py in getsourcelines(object)
#     953     raised if the source code cannot be retrieved."""
#     954     object = unwrap(object)
# --> 955     lines, lnum = findsource(object)
#     956
#     957     if istraceback(object):
#
# ~/miniconda3/envs/splai3/lib/python3.7/inspect.py in findsource(object)
#     784         lines = linecache.getlines(file)
#     785     if not lines:
# --> 786         raise OSError('could not get source code')
#     787
#     788     if ismodule(object):
#
# OSError: could not get source code
